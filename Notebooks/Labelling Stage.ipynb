# %% [markdown]
# # Labelling Stage

# %% [markdown]
# Content Warning:
#
# - an example item in the "Labelling Scheme" discusses suicide.
# - random selections of 19th C. newspaper text content are also displayed with no ability to filter for content.

# %% [markdown]
# ## Overview

# %% [markdown]
# This notebook sets out the labelling process for corpus items. This requires, broadly speaking, two sets of inputs. At any stage we have a `candidate_corpus` from the corpus exploration phase of the process. These items should be increasingly close to our desired corpus as the process of corpus construction continues. However, we will also require a broad sample of the kind of items that we _don't_ want. This is done by including a random sample of items from the processed dataset.
#
# This notebook sets out :
#
# 1. the import of data from previous stages,
# 2. the construction of a labelling scheme, and
# 3. the creation and use of a labelling dashboard.

# %% [markdown]
# ## Imports and Setup

# %%
import pickle
import random

import pandas as pd

from jupyter_dash import JupyterDash
from dash import dcc
from dash import html as dash_html
from dash.dependencies import Input, Output, State

# Provide a path to the location of the processed dataset.
dataset_path = '../Dataset/processed-data/'

# The following lines load a dictionary of correspondences needed
# to generate Papers Past URLs.
with open('../Pickles/codes2names_web.pickle', 'rb') as fin:
    CODES2NAMES_WEB = pickle.load(fin)
with open('../Pickles/codes2names.pickle', 'rb') as fin:
    CODES2NAMES = pickle.load(fin)

# %% [markdown]
# As in the corpous exploration notebook, we keep track of the iteration with a variable.

# %%
ITERATION = 1

# %% [markdown]
# This notebook will predominantly cover the first iteration of the process. In the first iteration, nothing will have been labelled.

# %% [markdown]
# The following code will load the required labels. If you are part way through an iteration (labelling can take a while!), then set `in_progress` to `True`. If there are no labels yet in the current iteration, and empty set of labels will be created.

# %%
in_progress = False

if in_progress:
    desired_iteration = ITERATION
else:
    desired_iteration = ITERATION - 1

try:
    labels = pd.read_pickle(f'../Labels/labels_{desired_iteration}.tar.gz'),
except FileNotFoundError:
    labels = pd.DataFrame(
        columns=[
            'Text', 'Notes',  # See below for discussion of labels.
            'Philosophy', 'Philosophy Type', 'Readable', 'Writing Type', 
        ]
    )

# %% [markdown]
# We load the candidate corpus.

# %%
candidate_corpus = pd.read_pickle(f'../Corpora/candidate_corpus_{ITERATION-1}.tar.gz')

# %% [markdown]
# We then take a random sample of the processed dataset. By default, we take a sample of 500. ***NB: random_state argument to the sample method means that each time this is run the sample will be the same. I have included it for reproducability, but the same state should not be used for two distinct iterations.***

# %%
sample_size = 500
# Load out list of all articles with the file they are contained in.
items_by_slice = pd.read_pickle('../Dataset/processed-data/meta/items_by_slice.tar.gz')
sample = items_by_slice.sample(sample_size, random_state=100).sort_values(by="Slice")
sample
# Out:
#                                                                   Title  Slice
# FS_18891130_ARTICLE21                             Wellington Land Board      0
# WEST_18710601_ARTICLE12                                  ENGLISH ITEMS.      0
# FS_18840306_ARTICLE5                              Local & General News.      0
# WT_18840814_ARTICLE3           ABSTRACT OF SALES BY AUCTION.  This Day.      0
# FS_18931026_ARTICLE1                                             BIRTH.      0
# ...                                                                 ...    ...
# TS_18830903_ARTICLE1                                         LYTTELTON.     25
# NEM_18891104_ARTICLE18   " The Spectator" on the Dominion of Australia.     25
# LT_18910408_ARTICLE30                       PUBLIC SERVICE ASSOCIATION.     25
# TC_18980421_ARTICLE33                                 Marine Engineers.     25
# NEM_18891106_ARTICLE13                            The Paris Exhibition.     25
#
# [500 rows x 2 columns]

# %% [markdown]
# We now iterate through the required slices, returning the desired items. We first define a function which, given the desired indices, returns a dataframe containing the required articles from our processed corpus. This can be used both for the random sample and for collecting any articles which we have reason to want to include but which are not in our candidate corpus.

# %%
def collect_articles_by_indices(indices, slices=list(range(26))): # "26" is the number of slices plus 1.
    filtered_dfs = []
    for i in slices:
        print(f"Loading corpus slice {i}")
        df = pd.read_pickle(f'../Dataset/processed-data/corpus_df_{i}.tar.gz')
        filtered_df = df.filter(indices, axis=0)
        filtered_dfs.append(filtered_df)
        del df
    
    desired_items = pd.concat(filtered_dfs)
    return desired_items

# %%
needed_slices = sample['Slice'].unique()
needed_slices
    
random_items = collect_articles_by_indices(sample.index, slices=needed_slices)
random_items
# Out:
# Loading corpus slice 0
# Loading corpus slice 1
# Loading corpus slice 2
# Loading corpus slice 3
# Loading corpus slice 4
# Loading corpus slice 5
# Loading corpus slice 6
# Loading corpus slice 7
# Loading corpus slice 8
# Loading corpus slice 9
# Loading corpus slice 10
# Loading corpus slice 11
# Loading corpus slice 12
# Loading corpus slice 13
# Loading corpus slice 14
# Loading corpus slice 15
# Loading corpus slice 16
# Loading corpus slice 17
# Loading corpus slice 18
# Loading corpus slice 19
# Loading corpus slice 20
# Loading corpus slice 21
# Loading corpus slice 22
# Loading corpus slice 23
# Loading corpus slice 24
# Loading corpus slice 25
#                                                                   Title  \
# FS_18891130_ARTICLE21                             Wellington Land Board
# WEST_18710601_ARTICLE12                                  ENGLISH ITEMS.
# FS_18840306_ARTICLE5                              Local & General News.
# WT_18840814_ARTICLE3           ABSTRACT OF SALES BY AUCTION.  This Day.
# FS_18931026_ARTICLE1                                             BIRTH.
# ...                                                                 ...
# TS_18830903_ARTICLE1                                         LYTTELTON.
# NEM_18891104_ARTICLE18   " The Spectator" on the Dominion of Australia.
# LT_18910408_ARTICLE30                       PUBLIC SERVICE ASSOCIATION.
# TC_18980421_ARTICLE33                                 Marine Engineers.
# NEM_18891106_ARTICLE13                            The Paris Exhibition.
#
#                                                                       Text
# FS_18891130_ARTICLE21    [The usual monthly meeting of the Land Board w...
# WEST_18710601_ARTICLE12  [The Rev. J. C. Reichardt says:— '"According t...
# FS_18840306_ARTICLE5     [The Borough Council will meet this evening at...
# WT_18840814_ARTICLE3     [Mb J. S. Buokland, at the Cambridge Yards, at...
# FS_18931026_ARTICLE1     [Bkooks.— At Feilding, ou October 17tb, tho wi...
# ...                                                                    ...
# TS_18830903_ARTICLE1     [ABBTTBB. Baft. S— Wanoko, «.e., a7B tons, Nev...
# NEM_18891104_ARTICLE18   [London, November 3. The Spectator considers t...
# LT_18910408_ARTICLE30    [[Per Press Association.] WELLINGTON. April 7....
# TC_18980421_ARTICLE33    [Presentation., Wellington April 19. The Hon M...
# NEM_18891106_ARTICLE13   [Paris, November 5. Comta De Jouffray D'Abbans...
#
# [500 rows x 2 columns]

# %% [markdown]
# ### Special case: loading articles not in candidate corpus

# %% [markdown]
# If you want to load additional items, enter them in the empty list below and run the following cell. You will need to enter the article codes in form NEWSPAPER-CODE_DATE_ARTICLE-NUMBER.

# %%
desired_indices = [ # Here is a sample list of articles of interest for labelling.
    'LT_18990211_ARTICLE29', 
    'DSC_18601207_ARTICLE27',
    'OW_18511018_ARTICLE10', 
    'DSC_18520629_ARTICLE8',
    'DSC_18691229_ARTICLE17',
    'OW_18861112_ARTICLE129',
    'ESD_18760108_ARTICLE30',
    'OW_18601006_ARTICLE1',
    'LT_18690930_ARTICLE17',
    'NZTIM_18891129_ARTICLE33',
    'WEST_18720827_ARTICLE2',
    'CHP_18680716_ARTICLE12',
    'AS_18821014_ARTICLE10',
    'WT_18900422_ARTICLE8',
    'CHP_18940423_ARTICLE56',
    'AG_18840116_ARTICLE5',
    'MS_18830117_ARTICLE19',
    'GRA_18970305_ARTICLE3',
    'LT_18800611_ARTICLE5',
    'AG_18910526_ARTICLE8'
]
additional_items = collect_articles_by_indices(desired_indices)
# Out:
# Loading corpus slice 0
# Loading corpus slice 1
# Loading corpus slice 2
# Loading corpus slice 3
# Loading corpus slice 4
# Loading corpus slice 5
# Loading corpus slice 6
# Loading corpus slice 7
# Loading corpus slice 8
# Loading corpus slice 9
# Loading corpus slice 10
# Loading corpus slice 11
# Loading corpus slice 12
# Loading corpus slice 13
# Loading corpus slice 14
# Loading corpus slice 15
# Loading corpus slice 16
# Loading corpus slice 17
# Loading corpus slice 18
# Loading corpus slice 19
# Loading corpus slice 20
# Loading corpus slice 21
# Loading corpus slice 22
# Loading corpus slice 23
# Loading corpus slice 24
# Loading corpus slice 25

# %%
additional_items
# Out:
#                                                                       Title  \
# WEST_18720827_ARTICLE2                 VESSELS ANNOUNCED TO LEAVE WESTPORT.
# WT_18900422_ARTICLE8                                                 Death.
# LT_18990211_ARTICLE29                          THE ROMANCE OF MOTHER EARTH.
# LT_18690930_ARTICLE17                   MR HUXLEY AND SCIENTIFIC EDUCATION.
# LT_18800611_ARTICLE5                                              SHIPPING.
# GRA_18970305_ARTICLE3                                           MAILS CLOSE
# ESD_18760108_ARTICLE30                                              REVIEW.
# NZTIM_18891129_ARTICLE33                      THE RELIGION OF SELF-RESPECT.
# AS_18821014_ARTICLE10                        Meetings, Entertainments, Etc.
# DSC_18520629_ARTICLE8                      Lecture on " Secular Education."
# CHP_18680716_ARTICLE12                  The Press. THURSDAY, JULY 16, 1868.
# CHP_18940423_ARTICLE56                                             HUNTING.
# DSC_18601207_ARTICLE27    THE INTERNATIONAL STATISTICAL CONGRESS.  THE P...
# DSC_18691229_ARTICLE17                   A SCHOOL OF SCIENCE FOR AUCKLAiND.
# OW_18511018_ARTICLE10                                      THE WORKING MAN,
# OW_18861112_ARTICLE129                                          LITERATURE.
# OW_18601006_ARTICLE1                       LECTURE. BY JOHN M'GLASHAN, ESQ.
# AG_18840116_ARTICLE5                                     TRAVELLERS’ GUIDE.
# AG_18910526_ARTICLE8                                          RETRENCHMENT.
# MS_18830117_ARTICLE19                                     Local Government.
#
#                                                                        Text
# WEST_18720827_ARTICLE2    [Chalks Edward, on Thursday next, for Nelson, ...
# WT_18900422_ARTICLE8      [Walwouth.—On April 18fch, at Tauwhare, Jane, ...
# LT_18990211_ARTICLE29     [Lv his “ Romance of the Earth ” Professor Bic...
# LT_18690930_ARTICLE17     [{Lancet.) la the July number of Macmillan's M...
# LT_18800611_ARTICLE5      [LYTTELTON., arrived. ~ , T . in_Wallinffton. ...
# GRA_18970305_ARTICLE3     [This day— For Dunedln, per Herald, at 11 am. ...
# ESD_18760108_ARTICLE30    [The New Zealand Magazine, a quarterly Journal...
# NZTIM_18891129_ARTICLE33  [Self-respejt is eminently a masculine quality...
# AS_18821014_ARTICLE10     [OCTOBBR 11, 1882., Abbott's Opera House— Speo...
# DSC_18520629_ARTICLE8     [(From the 'ScoUman.') Mr. George Combe delive...
# CHP_18680716_ARTICLE12    [It appears that the Government has instructed...
# CHP_18940423_ARTICLE56    [CHRISTCHUKCH HUNT CLUB., If the attendance wa...
# DSC_18601207_ARTICLE27    [1 The^ meeting in London, under the Presidenc...
# DSC_18691229_ARTICLE17    [Ix the present utilitarian age, when the nece...
# OW_18511018_ARTICLE10     [In the progress of society, and in a country ...
# OW_18861112_ARTICLE129    [BAYNE'S ESSAY ON CARLYLE. This is really a ma...
# OW_18601006_ARTICLE1      [The following able and instructive lecture, w...
# AG_18840116_ARTICLE5      [Trains Leave Ashburton for Ohrist ; church an...
# AG_18910526_ARTICLE8      [MR SPENCE'S ATTACK ON THE MINISTRY.., The Inv...
# MS_18830117_ARTICLE19     [At a meeting of representatives of the variou...

# %% [markdown]
# ## Labelling Scheme

# %% [markdown]
# At this point, we apply a labelling scheme to the articles. The labelling scheme used in the course of picking out a philosophy corpus is as follows:
#
# - Readable: True / false.
# - Philosophy: True / false.
# - Philosophy type: Religion and science / ethics and politics / Other.
# - Writing Type: report of public event / letter to the editor / first-order writing / other.
#
# The question of what counts as philosophy is, as widely noted, itself a contentious philosophical question (see, e.g. Midgley 2018; Agamben 2017; Priest 2006; Deleuze and Guattari 1991; Heidegger 1958; Jevons 1914). It is one of the shortcomings of this project that a more clear specialised topic was not selected at the outset. _However_, the fact that a useful corpus comes out at the other end suggests that _even in the case of vague labelling_ the method is acceptable.
#
# In any case, for our purposes and in order to count as 'philosophy' an article must either appeal to or argue about 'ultimate values' or 'ultimate reality'. This is in line with a conceptions of philosophy which were popular at the time.
#
# If there is a portion of an article which is desired, we will label the whole article as 'philosophy'. Unfortunately, this method is not good at dealing with composite articles in which, say, a series of topics are covered only one of which is philosophy. See, for instance, the philosophical discussion of suicide contained in this piece which is surrounded by other non-philosophical matter (https://paperspast.natlib.govt.nz/newspapers/AS18860821.2.33).

# %% [markdown]
# ## Labelling Dashboard

# %% [markdown]
# The labelling scheme above will be implemented using a `Dash` dashboard.

# %% [markdown]
# We want to have the date and newspaper more obviously displayed in our dashboard. We define a function to do this and apply it.

# %%
def add_title_and_year(df):
    """Add 'Newspaper', 'Year', and 'Date' column to dataframe with
    'Text' column."""
    df['Newspaper'] = df.index.map(lambda x: x[0:x.find('_')])
    df['Date'] = df.index.map(lambda x: x[x.find('_')+1:x.find('_')+9])
    
add_title_and_year(candidate_corpus)
add_title_and_year(random_items)
add_title_and_year(additional_articles)

# %% [markdown]
# ### Setting up labelling dashboard

# %% [markdown]
# #### Helper functions

# %% [markdown]
# We will need to display formatted article text.

# %%
def escape_markdown(string):
    """Escape characters which have functions in markdown strings.
    Return escaped string."""

    markdown_escape_chars = r"\`*_{}[]<>()#+-.!|"
    for escape_char in markdown_escape_chars:
        string = string.replace(escape_char, "\\"+escape_char)

    return string

def text_as_markdown(index, dataframe, boldface=None):
    """Render article corresponding to index in dataframe as markdown
    string. Any matches for boldface are rendered in bold.
    """

    date = index[index.find('_')+1:index.find('_')+9]
    newspaper = index[0:index.find('_')]

    title = (dataframe.loc[index, 'Title'])
    title = escape_markdown(title)

    web_prefix = "https://paperspast.natlib.govt.nz/newspapers/"
    year = date[0:4]
    month = date[4:6]
    day = date[6:8]
    web_address = f"{web_prefix}{CODES2NAMES_WEB[newspaper]}/{year}/{month}/{day}"

    text_blocks = dataframe.loc[index, 'Text']
    text = ''
    for block in text_blocks:
        paragraph = escape_markdown(block)
        text += paragraph + '\n\n'

    if boldface:
        match = re.search(boldface, text)
        if match:
            text = re.sub(boldface, f'***{match.group(0)}***', text)

    markdown_text = f"""## {title}

*{CODES2NAMES[newspaper]}*

{day}/{month}/{year}

[View issue on Papers Past]({web_address})

{text}
"""

    return markdown_text

# %% [markdown]
# ### Selecting articles for labelling

# %% [markdown]
# I've set up this notebook such that we label from one of the sources listed above at a time. That is, we can label the random sample of articles, named articles from our candidate corpus, all articles from the candidate corpus, or any additional articles which we might have loaded from the processed dataset.

# %% [markdown]
# Enter any list of items from the candidate corpus selected for labelling during the corpus exploration stage:

# %%
items_to_label = []

# %% [markdown]
# The initial value here sets up the random items to be labelled. Alternatives are listed in the comment.

# %%
to_label = random_items # alternative options: candidate_corpus, candidate_corpus.loc[items_to_label, ], additional_items.

# %% [markdown]
# We reformat the article names for use in the dashboard.

# %%
item_names_formatted = [
    {'label': f'{to_label["Title"].loc[i]} ({i})', 'value': i} 
    for i in to_label.index
]

# %%
item_names_formatted
# Out:
# [{'label': 'Wellington Land Board (FS_18891130_ARTICLE21)',
#   'value': 'FS_18891130_ARTICLE21'},
#  {'label': 'ENGLISH ITEMS. (WEST_18710601_ARTICLE12)',
#   'value': 'WEST_18710601_ARTICLE12'},
#  {'label': 'Local & General News. (FS_18840306_ARTICLE5)',
#   'value': 'FS_18840306_ARTICLE5'},
#  {'label': 'ABSTRACT OF SALES BY AUCTION.  This Day. (WT_18840814_ARTICLE3)',
#   'value': 'WT_18840814_ARTICLE3'},
#  {'label': 'BIRTH. (FS_18931026_ARTICLE1)', 'value': 'FS_18931026_ARTICLE1'},
#  {'label': 'COMMERCIAL. (FS_18830131_ARTICLE2)',
#   'value': 'FS_18830131_ARTICLE2'},
#  {'label': 'AUSTRALIAN NEWS. (FS_18880920_ARTICLE7)',
#   'value': 'FS_18880920_ARTICLE7'},
#  {'label': 'THE HOUSEHOLD OF McNEIL. (DTN_18900930_ARTICLE39)',
#   'value': 'DTN_18900930_ARTICLE39'},
#  {'label': 'The Daily Telegraph. TUESDAY DECEMBER 2, 1890 (DTN_18901202_ARTICLE5)',
#   'value': 'DTN_18901202_ARTICLE5'},
#  {'label': 'DEATH OF CARDINAL MANNING. (WT_18920116_ARTICLE16)',
#   'value': 'WT_18920116_ARTICLE16'},
#  {'label': "AUSTRALIAN.  [REUTER'S TELEGRAMS.]  Sydney, February 5. (WT_18860209_ARTICLE23)",
#   'value': 'WT_18860209_ARTICLE23'},
#  {'label': 'DEPARTURES. (DTN_18910820_ARTICLE3)',
#   'value': 'DTN_18910820_ARTICLE3'},
#  {'label': 'THE NEW ZEALAND STUD BOOK. (GLOBE_18810928_ARTICLE22)',
#   'value': 'GLOBE_18810928_ARTICLE22'},
#  {'label': 'NEW ZEALAND. (GLOBE_18810516_ARTICLE7)',
#   'value': 'GLOBE_18810516_ARTICLE7'},
#  {'label': 'UNTITLED (WT_18930411_ARTICLE21)',
#   'value': 'WT_18930411_ARTICLE21'},
#  {'label': 'SPORTING. (DTN_18860809_ARTICLE12)',
#   'value': 'DTN_18860809_ARTICLE12'},
#  {'label': 'SPORTING INTELLIGENCE. (DTN_18831106_ARTICLE6)',
#   'value': 'DTN_18831106_ARTICLE6'},
#  {'label': "To-day's Developments. (DTN_18900920_ARTICLE18)",
#   'value': 'DTN_18900920_ARTICLE18'},
#  {'label': 'GENERAL ASSEMBLY. (GLOBE_18820909_ARTICLE17)',
#   'value': 'GLOBE_18820909_ARTICLE17'},
#  {'label': 'EXPERIMENTS IN POTATO CULTURE. (WT_18940904_ARTICLE42)',
#   'value': 'WT_18940904_ARTICLE42'},
#  {'label': 'MAGISTRATES COURTS. (GLOBE_18780503_ARTICLE8)',
#   'value': 'GLOBE_18780503_ARTICLE8'},
#  {'label': 'GENERAL ASSEMBLY. (WT_18930715_ARTICLE11)',
#   'value': 'WT_18930715_ARTICLE11'},
#  {'label': 'THE DIRECT VETO. (LT_18930803_ARTICLE8)',
#   'value': 'LT_18930803_ARTICLE8'},
#  {'label': 'The Star.  TUESDAY, FEB. 28, 1893.  The King of New Zealand and his Critic. (TS_18930228_ARTICLE6)',
#   'value': 'TS_18930228_ARTICLE6'},
#  {'label': 'MAIL NOTICES. (LT_18880406_ARTICLE17)',
#   'value': 'LT_18880406_ARTICLE17'},
#  {'label': 'DEATH OF THE HON. CONSTANTINE AUGUSTUS DILLON. (LT_18530521_ARTICLE14)',
#   'value': 'LT_18530521_ARTICLE14'},
#  {'label': 'THE MIDLAND RAILWAY. (LT_18991019_ARTICLE26)',
#   'value': 'LT_18991019_ARTICLE26'},
#  {'label': 'COMMERCIAL. (LT_18800323_ARTICLE7)',
#   'value': 'LT_18800323_ARTICLE7'},
#  {'label': 'ACCLIMATISATION SOCIETY. (LT_18860708_ARTICLE14)',
#   'value': 'LT_18860708_ARTICLE14'},
#  {'label': 'LITERATURE. (TS_18900729_ARTICLE1)',
#   'value': 'TS_18900729_ARTICLE1'},
#  {'label': 'ACCLIMATISATION SOCIETY. (TS_18760726_ARTICLE12)',
#   'value': 'TS_18760726_ARTICLE12'},
#  {'label': 'ACCIDENTS AND FATALITIES. (TS_18901227_ARTICLE52)',
#   'value': 'TS_18901227_ARTICLE52'},
#  {'label': 'THE CHURCH PROPERTY TRUSTEES AND THEIR EXECUTIVE COMMITTEE. (LT_18890518_ARTICLE42)',
#   'value': 'LT_18890518_ARTICLE42'},
#  {'label': 'TOWN & COUNTRY. (LT_18770526_ARTICLE15)',
#   'value': 'LT_18770526_ARTICLE15'},
#  {'label': 'EXTRAORDINARY BARGAINS. (TS_18951218_ARTICLE53)',
#   'value': 'TS_18951218_ARTICLE53'},
#  {'label': "ROYALTY'S CLEVER WOMEN. (TS_18990422_ARTICLE20)",
#   'value': 'TS_18990422_ARTICLE20'},
#  {'label': 'VITAL STATISTICS. (TS_18880120_ARTICLE48)',
#   'value': 'TS_18880120_ARTICLE48'},
#  {'label': 'LAND BOARD. (LT_18950316_ARTICLE9)',
#   'value': 'LT_18950316_ARTICLE9'},
#  {'label': 'AUCTION SALES—THIS DAY. (LT_18930415_ARTICLE14)',
#   'value': 'LT_18930415_ARTICLE14'},
#  {'label': 'SPORTING. (LT_18960723_ARTICLE39)',
#   'value': 'LT_18960723_ARTICLE39'},
#  {'label': 'MAIL NOTICES. (LT_18970603_ARTICLE18)',
#   'value': 'LT_18970603_ARTICLE18'},
#  {'label': 'COMMERCIAL. (LT_18790412_ARTICLE10)',
#   'value': 'LT_18790412_ARTICLE10'},
#  {'label': 'COMMERCIAL. (TS_18750319_ARTICLE11)',
#   'value': 'TS_18750319_ARTICLE11'},
#  {'label': 'SUPREME COURT. (LT_18800501_ARTICLE4)',
#   'value': 'LT_18800501_ARTICLE4'},
#  {'label': 'LYTTELTON REGATTA. (LT_18660113_ARTICLE24)',
#   'value': 'LT_18660113_ARTICLE24'},
#  {'label': 'SHIPPING TELEGRAMS (TS_18981201_ARTICLE40)',
#   'value': 'TS_18981201_ARTICLE40'},
#  {'label': 'South Canterbury J.C. (TS_18900918_ARTICLE18)',
#   'value': 'TS_18900918_ARTICLE18'},
#  {'label': 'The Lyttelton Times. TUESDAY. JULY 24, 1894. (LT_18940724_ARTICLE22)',
#   'value': 'LT_18940724_ARTICLE22'},
#  {'label': 'SHIPPING TELEGRAMS. (TS_18870819_ARTICLE5)',
#   'value': 'TS_18870819_ARTICLE5'},
#  {'label': 'BRITISH AND FOREIGN (LT_18940927_ARTICLE35)',
#   'value': 'LT_18940927_ARTICLE35'},
#  {'label': 'COMMERCIAL. (LT_18740408_ARTICLE2)',
#   'value': 'LT_18740408_ARTICLE2'},
#  {'label': 'THE THREE SHIPMATES. (TS_18930411_ARTICLE4)',
#   'value': 'TS_18930411_ARTICLE4'},
#  {'label': 'LEGISLATIVE COUNCIL. (TS_18800818_ARTICLE29)',
#   'value': 'TS_18800818_ARTICLE29'},
#  {'label': 'ACTION AGAINST A RAILWAY COMPANY. (LT_18840418_ARTICLE20)',
#   'value': 'LT_18840418_ARTICLE20'},
#  {'label': 'The Star.  THURSDAY, MARCH 9, 1893.  The "Free Labour" Delusion. (TS_18930309_ARTICLE10)',
#   'value': 'TS_18930309_ARTICLE10'},
#  {'label': 'MONETARY AND COMMERCIAL. (TS_18940702_ARTICLE7)',
#   'value': 'TS_18940702_ARTICLE7'},
#  {'label': 'COLONIAL AGRICULTURAL MACHINERY. (LT_18931223_ARTICLE13)',
#   'value': 'LT_18931223_ARTICLE13'},
#  {'label': 'PRESIDENTS CUP MATCHES. (TS_18960316_ARTICLE4)',
#   'value': 'TS_18960316_ARTICLE4'},
#  {'label': 'NOTES ON THE WAR. (TS_18701029_ARTICLE8)',
#   'value': 'TS_18701029_ARTICLE8'},
#  {'label': 'DEATHS. (TS_18970109_ARTICLE23)',
#   'value': 'TS_18970109_ARTICLE23'},
#  {'label': 'THE FARMER (BH_18950326_ARTICLE36)',
#   'value': 'BH_18950326_ARTICLE36'},
#  {'label': 'THE WAR IN THE EAST. (THD_18941011_ARTICLE10)',
#   'value': 'THD_18941011_ARTICLE10'},
#  {'label': 'A Necessary Precuation. (TS_18890627_ARTICLE49)',
#   'value': 'TS_18890627_ARTICLE49'},
#  {'label': 'A MILITARY RIOT. (THD_18881011_ARTICLE27)',
#   'value': 'THD_18881011_ARTICLE27'},
#  {'label': 'THE TROUBLE IN  CRETE. (TS_18970217_ARTICLE48)',
#   'value': 'TS_18970217_ARTICLE48'},
#  {'label': 'WEEKLY LIVE STOCK AND PRODUCE REPORT. (BH_18920826_ARTICLE3)',
#   'value': 'BH_18920826_ARTICLE3'},
#  {'label': 'THE OPIHI BRIDGE. (THD_18781214_ARTICLE19)',
#   'value': 'THD_18781214_ARTICLE19'},
#  {'label': 'The Star.  WEDNESDAY, JANUARY 30, 1889.  Logic Wanted. (TS_18890130_ARTICLE18)',
#   'value': 'TS_18890130_ARTICLE18'},
#  {'label': 'AUSTRALIAN CABLE. (THD_18890417_ARTICLE11)',
#   'value': 'THD_18890417_ARTICLE11'},
#  {'label': 'LECTURES ON THE REFORM TION. (BH_18660816_ARTICLE20)',
#   'value': 'BH_18660816_ARTICLE20'},
#  {'label': 'Ladies. (BH_18990822_ARTICLE27)',
#   'value': 'BH_18990822_ARTICLE27'},
#  {'label': 'WHY MEN DO NOT MARRY. (BH_18950702_ARTICLE24)',
#   'value': 'BH_18950702_ARTICLE24'},
#  {'label': 'SECOND EDITION. (TS_18820224_ARTICLE11)',
#   'value': 'TS_18820224_ARTICLE11'},
#  {'label': 'DUNEDIN HORSE SALEYARDS. (BH_18961222_ARTICLE38)',
#   'value': 'BH_18961222_ARTICLE38'},
#  {'label': 'THE SPARROW QUESTION. (THD_18701228_ARTICLE29)',
#   'value': 'THD_18701228_ARTICLE29'},
#  {'label': 'Addington Market. (TS_18891113_ARTICLE26)',
#   'value': 'TS_18891113_ARTICLE26'},
#  {'label': 'SPORTING. (THD_18810609_ARTICLE15)',
#   'value': 'THD_18810609_ARTICLE15'},
#  {'label': 'S-M. Court Woodville (WOODEX_18951206_ARTICLE8)',
#   'value': 'WOODEX_18951206_ARTICLE8'},
#  {'label': "ARTHUR MACDONALD'S BANKRUPTCY. (THD_18920623_ARTICLE20)",
#   'value': 'THD_18920623_ARTICLE20'},
#  {'label': 'NEW ZEALAND RAILWAYS. (WOODEX_18880228_ARTICLE23)',
#   'value': 'WOODEX_18880228_ARTICLE23'},
#  {'label': 'TWO POINTED QUESTIONS  ANSWERED. (CL_18990616_ARTICLE40)',
#   'value': 'CL_18990616_ARTICLE40'},
#  {'label': 'A Matabele Hero. (WOODEX_18950918_ARTICLE26)',
#   'value': 'WOODEX_18950918_ARTICLE26'},
#  {'label': 'A SCHOONER MISSING. (THD_18820722_ARTICLE4)',
#   'value': 'THD_18820722_ARTICLE4'},
#  {'label': 'THE WESLEYAN METHODIST CONFERENCE. (THD_18990303_ARTICLE19)',
#   'value': 'THD_18990303_ARTICLE19'},
#  {'label': 'THE S.S. ARAWA. (THD_18840815_ARTICLE2)',
#   'value': 'THD_18840815_ARTICLE2'},
#  {'label': 'ESTEEMED EVERYWHERE DV EVERYBODY. (THD_18900510_ARTICLE31)',
#   'value': 'THD_18900510_ARTICLE31'},
#  {'label': 'LATEST CABLEGRAMS (CL_18960327_ARTICLE9)',
#   'value': 'CL_18960327_ARTICLE9'},
#  {'label': 'POST OFFICE NOTICE. (THD_18651215_ARTICLE3)',
#   'value': 'THD_18651215_ARTICLE3'},
#  {'label': 'THE WELLINGTON MURDER. (SCANT_18960904_ARTICLE9)',
#   'value': 'SCANT_18960904_ARTICLE9'},
#  {'label': 'AUSTRALIAN. (SCANT_18931208_ARTICLE5)',
#   'value': 'SCANT_18931208_ARTICLE5'},
#  {'label': 'A MODERN REIGN OF TERROR. (WSTAR_18980312_ARTICLE51)',
#   'value': 'WSTAR_18980312_ARTICLE51'},
#  {'label': 'THE INTERNATIONAL SOCIETY. (GRA_18731212_ARTICLE16)',
#   'value': 'GRA_18731212_ARTICLE16'},
#  {'label': 'THE  Grey River Argus.  PUBLISHED DAILY.  TUESDAY, JULY 17,1883. (GRA_18830717_ARTICLE5)',
#   'value': 'GRA_18830717_ARTICLE5'},
#  {'label': 'MAIL NOTICES. (SCANT_18831112_ARTICLE2)',
#   'value': 'SCANT_18831112_ARTICLE2'},
#  {'label': 'TRADE AND LABOR REPORTS. (GRA_18831106_ARTICLE16)',
#   'value': 'GRA_18831106_ARTICLE16'},
#  {'label': 'A SAMPLE OF ANARCHIST LITERATURE. (GRA_18920604_ARTICLE12)',
#   'value': 'GRA_18920604_ARTICLE12'},
#  {'label': 'SHOOTING. (SCANT_18940126_ARTICLE9)',
#   'value': 'SCANT_18940126_ARTICLE9'},
#  {'label': 'THE  Grey River Argus.  PUBLISHED DAILY.  THURSDAY, MARGE 31, 1892. (GRA_18920331_ARTICLE5)',
#   'value': 'GRA_18920331_ARTICLE5'},
#  {'label': 'PAROA HOSPITAL COMMITTEE.  [TO THE EDITOR.] (GRA_18810602_ARTICLE30)',
#   'value': 'GRA_18810602_ARTICLE30'},
#  {'label': 'HOKITIKA RACES. (GRA_18771227_ARTICLE6)',
#   'value': 'GRA_18771227_ARTICLE6'},
#  {'label': 'THE BRUNNER FUND. (SCANT_18960420_ARTICLE10)',
#   'value': 'SCANT_18960420_ARTICLE10'},
#  {'label': 'NEW ZEALAND. (SCANT_18941224_ARTICLE25)',
#   'value': 'SCANT_18941224_ARTICLE25'},
#  {'label': 'Political Addresses. (SCANT_18890604_ARTICLE12)',
#   'value': 'SCANT_18890604_ARTICLE12'},
#  {'label': 'AUCTION SALES—TO-MORROW. (SCANT_18791211_ARTICLE2)',
#   'value': 'SCANT_18791211_ARTICLE2'},
#  {'label': 'AUSTRALIAN. (SCANT_18880111_ARTICLE6)',
#   'value': 'SCANT_18880111_ARTICLE6'},
#  {'label': 'FOREIGN PARCEL POST. (SCANT_18931222_ARTICLE25)',
#   'value': 'SCANT_18931222_ARTICLE25'},
#  {'label': 'UNTITLED (GRA_18831208_ARTICLE29)',
#   'value': 'GRA_18831208_ARTICLE29'},
#  {'label': 'A PLEASURE AND A DUTY. (GRA_18991116_ARTICLE6)',
#   'value': 'GRA_18991116_ARTICLE6'},
#  {'label': 'AUSTRALIA NEWS. (GRA_18940927_ARTICLE11)',
#   'value': 'GRA_18940927_ARTICLE11'},
#  {'label': 'PRIMITIVE METHODIST CONFER.  ENCE. (GRA_18870127_ARTICLE19)',
#   'value': 'GRA_18870127_ARTICLE19'},
#  {'label': 'ELECTORAL DISTRICT OF GREY VALLEY. (GRA_18740519_ARTICLE8)',
#   'value': 'GRA_18740519_ARTICLE8'},
#  {'label': 'BRITISH AND FOREIGN. (SCANT_18940103_ARTICLE1)',
#   'value': 'SCANT_18940103_ARTICLE1'},
#  {'label': 'IN THE SOUDAN (HAST_18980910_ARTICLE20)',
#   'value': 'HAST_18980910_ARTICLE20'},
#  {'label': 'The Vancouver Service. (HAST_18990320_ARTICLE28)',
#   'value': 'HAST_18990320_ARTICLE28'},
#  {'label': 'GOOD TEMPLARY. (ESD_18980513_ARTICLE10)',
#   'value': 'ESD_18980513_ARTICLE10'},
#  {'label': 'GENERAL NEWS. (HAST_18960905_ARTICLE20)',
#   'value': 'HAST_18960905_ARTICLE20'},
#  {'label': 'THE WOOL SALES. (ESD_18940119_ARTICLE18)',
#   'value': 'ESD_18940119_ARTICLE18'},
#  {'label': 'Iolanthe. (HAST_18960924_ARTICLE5)',
#   'value': 'HAST_18960924_ARTICLE5'},
#  {'label': 'THE FRONT. (WAIST_18681010_ARTICLE11)',
#   'value': 'WAIST_18681010_ARTICLE11'},
#  {'label': 'Crushing Defeat of Bishop Moran. (WAIST_18830124_ARTICLE7)',
#   'value': 'WAIST_18830124_ARTICLE7'},
#  {'label': 'THE ROSLYN TRAM ON SUNDAY. (ESD_18940804_ARTICLE28)',
#   'value': 'ESD_18940804_ARTICLE28'},
#  {'label': 'JUBILEE ADDRESSES. (ESD_18870625_ARTICLE38)',
#   'value': 'ESD_18870625_ARTICLE38'},
#  {'label': 'PERSONAL. (ESD_18970806_ARTICLE43)',
#   'value': 'ESD_18970806_ARTICLE43'},
#  {'label': 'AMUSEMENTS THIS EVENING. (ESD_18651108_ARTICLE3)',
#   'value': 'ESD_18651108_ARTICLE3'},
#  {'label': 'NEW INSOLVENTS. (ESD_18880420_ARTICLE16)',
#   'value': 'ESD_18880420_ARTICLE16'},
#  {'label': 'RESIDENT MAGISTRATE’S COURT. (ESD_18710614_ARTICLE8)',
#   'value': 'ESD_18710614_ARTICLE8'},
#  {'label': 'THE CRETAN CRISIS. (ESD_18970412_ARTICLE16)',
#   'value': 'ESD_18970412_ARTICLE16'},
#  {'label': 'SOCIAL MEETINGS. (ESD_18951004_ARTICLE33)',
#   'value': 'ESD_18951004_ARTICLE33'},
#  {'label': 'Birth. (ESD_18790121_ARTICLE7)', 'value': 'ESD_18790121_ARTICLE7'},
#  {'label': 'FOOTLIGHT FLASHES. (ESD_18920616_ARTICLE29)',
#   'value': 'ESD_18920616_ARTICLE29'},
#  {'label': 'NEW ZEALAND EXHIBITION. (ESD_18890225_ARTICLE29)',
#   'value': 'ESD_18890225_ARTICLE29'},
#  {'label': 'PORT OF INVERCARGILL. (ST_18831108_ARTICLE2)',
#   'value': 'ST_18831108_ARTICLE2'},
#  {'label': 'MR CANNING AT GORE. (ST_18870924_ARTICLE17)',
#   'value': 'ST_18870924_ARTICLE17'},
#  {'label': 'The Southland Times.  PUBLISHED DAILY. Luceo Non Uro. MONDAY, 31ST JULY, 1882. (ST_18820731_ARTICLE9)',
#   'value': 'ST_18820731_ARTICLE9'},
#  {'label': 'INTERPROVINCIAL. (ESD_18800915_ARTICLE14)',
#   'value': 'ESD_18800915_ARTICLE14'},
#  {'label': 'ATTEMPTED POISONING. (WC_18981005_ARTICLE14)',
#   'value': 'WC_18981005_ARTICLE14'},
#  {'label': 'AN ENGLISH CASE OF SIAMESE TWINS. (ST_18690915_ARTICLE28)',
#   'value': 'ST_18690915_ARTICLE28'},
#  {'label': 'SPECIAL TELEGRAM. (ESD_18970421_ARTICLE21)',
#   'value': 'ESD_18970421_ARTICLE21'},
#  {'label': 'The Southland Times  PUBLISHED DAILY.  Luceo Non Uro.  WEDNESDAY, JULY 27, 1881. (ST_18810727_ARTICLE7)',
#   'value': 'ST_18810727_ARTICLE7'},
#  {'label': 'The Southland Times  PUBLISHED EVERY MORNING. Luceo Non Uro.  SATURDAY, 9th OCTOBER, 1886. (ST_18861009_ARTICLE7)',
#   'value': 'ST_18861009_ARTICLE7'},
#  {'label': 'AMUSEMENTS, MEETINGS, &c. (ESD_18710828_ARTICLE4)',
#   'value': 'ESD_18710828_ARTICLE4'},
#  {'label': 'THE SEAMEN’S STRIKE. (ESD_18860115_ARTICLE16)',
#   'value': 'ESD_18860115_ARTICLE16'},
#  {'label': 'THE KIWI INQUIRY. (WC_18940510_ARTICLE18)',
#   'value': 'WC_18940510_ARTICLE18'},
#  {'label': 'YELLOW SPECTACLES (WC_18970303_ARTICLE36)',
#   'value': 'WC_18970303_ARTICLE36'},
#  {'label': 'FATAL DRAG ACCCIDENT. (NA_18930204_ARTICLE16)',
#   'value': 'NA_18930204_ARTICLE16'},
#  {'label': 'AFFAIRS IN TONGA. (WC_18870224_ARTICLE20)',
#   'value': 'WC_18870224_ARTICLE20'},
#  {'label': 'LATEST (WC_18910824_ARTICLE9)', 'value': 'WC_18910824_ARTICLE9'},
#  {'label': 'AUCKLAND. (WC_18790218_ARTICLE6)',
#   'value': 'WC_18790218_ARTICLE6'},
#  {'label': 'PALMERSTON NORTH. (WC_18870721_ARTICLE17)',
#   'value': 'WC_18870721_ARTICLE17'},
#  {'label': 'LOCAL AND GENERAL. (WC_18870314_ARTICLE4)',
#   'value': 'WC_18870314_ARTICLE4'},
#  {'label': 'SPECIAL SETTLEMENT APPLICATION. (NZTIM_18920517_ARTICLE31)',
#   'value': 'NZTIM_18920517_ARTICLE31'},
#  {'label': 'MEMORANDA. (NZTIM_18821021_ARTICLE9)',
#   'value': 'NZTIM_18821021_ARTICLE9'},
#  {'label': 'UNTITLED (NZTIM_18800427_ARTICLE6)',
#   'value': 'NZTIM_18800427_ARTICLE6'},
#  {'label': 'POLITICAL NOTES. (NZTIM_18920902_ARTICLE7)',
#   'value': 'NZTIM_18920902_ARTICLE7'},
#  {'label': 'A COLONY’S GIFT TO THE EMPIRE. (NZTIM_18970713_ARTICLE19)',
#   'value': 'NZTIM_18970713_ARTICLE19'},
#  {'label': 'AUCTION SALE OF PROPERTIES. (NZTIM_18980415_ARTICLE39)',
#   'value': 'NZTIM_18980415_ARTICLE39'},
#  {'label': 'The New Zealand Times (PUBLISHED DAILY.) FRIDAY, NOVEMBER 23, 1883. (NZTIM_18831123_ARTICLE4)',
#   'value': 'NZTIM_18831123_ARTICLE4'},
#  {'label': 'UNTITLED (NZTIM_18971127_ARTICLE52)',
#   'value': 'NZTIM_18971127_ARTICLE52'},
#  {'label': 'IMPORTANT SALE OF HARBOUR BOARD LEASES. (NZTIM_18901217_ARTICLE22)',
#   'value': 'NZTIM_18901217_ARTICLE22'},
#  {'label': 'PARASITE PROMOTERS. (MIC_18990218_ARTICLE31)',
#   'value': 'MIC_18990218_ARTICLE31'},
#  {'label': '"PEEPING TOM." (MIC_18820325_ARTICLE5)',
#   'value': 'MIC_18820325_ARTICLE5'},
#  {'label': 'RAILWAY EXTENSION TO TE ARO. (NZTIM_18900723_ARTICLE18)',
#   'value': 'NZTIM_18900723_ARTICLE18'},
#  {'label': 'AMENDMENT OF THE LICENSING ACT, 1881. (NZTIM_18820616_ARTICLE55)',
#   'value': 'NZTIM_18820616_ARTICLE55'},
#  {'label': 'LATE CABLE NEWS (NZTIM_18891024_ARTICLE19)',
#   'value': 'NZTIM_18891024_ARTICLE19'},
#  {'label': 'AUSTRALIAN. (NZTIM_18840424_ARTICLE19)',
#   'value': 'NZTIM_18840424_ARTICLE19'},
#  {'label': 'MASTERTON NEWS. (NZTIM_18921024_ARTICLE32)',
#   'value': 'NZTIM_18921024_ARTICLE32'},
#  {'label': 'POLITICAL (NZTIM_18930526_ARTICLE20)',
#   'value': 'NZTIM_18930526_ARTICLE20'},
#  {'label': 'DIAMOND RING STORY. (NZTIM_18830524_ARTICLE20)',
#   'value': 'NZTIM_18830524_ARTICLE20'},
#  {'label': 'THE COURTS. (MIC_18951221_ARTICLE10)',
#   'value': 'MIC_18951221_ARTICLE10'},
#  {'label': 'THE HURRICANE. (NZTIM_18930313_ARTICLE14)',
#   'value': 'NZTIM_18930313_ARTICLE14'},
#  {'label': 'UNTITLED (NZTIM_18810516_ARTICLE17)',
#   'value': 'NZTIM_18810516_ARTICLE17'},
#  {'label': 'UNTITLED (NZTIM_18880517_ARTICLE16)',
#   'value': 'NZTIM_18880517_ARTICLE16'},
#  {'label': 'A NARROW ESCAPE. (NZTIM_18911024_ARTICLE17)',
#   'value': 'NZTIM_18911024_ARTICLE17'},
#  {'label': 'BATTLE OF STORMBERG (NZTIM_18991216_ARTICLE48)',
#   'value': 'NZTIM_18991216_ARTICLE48'},
#  {'label': 'WRECKS. (NZTIM_18970326_ARTICLE35)',
#   'value': 'NZTIM_18970326_ARTICLE35'},
#  {'label': 'THE NEW TAY-BRIDGE. (MIC_18801127_ARTICLE26)',
#   'value': 'MIC_18801127_ARTICLE26'},
#  {'label': 'THE LADIES’ COLUMN. (NZTIM_18980416_ARTICLE46)',
#   'value': 'NZTIM_18980416_ARTICLE46'},
#  {'label': 'WELLINGTON, this day. PROSPECTING.—AN ENCOURAGING FIELD. (AS_18790913_ARTICLE23)',
#   'value': 'AS_18790913_ARTICLE23'},
#  {'label': "WARDEN'S COURT, CROMWELL. (CROMARG_18881211_ARTICLE4)",
#   'value': 'CROMARG_18881211_ARTICLE4'},
#  {'label': 'MISCELLANEOUS. (AS_18990906_ARTICLE17)',
#   'value': 'AS_18990906_ARTICLE17'},
#  {'label': 'Deaths. (AS_18940427_ARTICLE51)',
#   'value': 'AS_18940427_ARTICLE51'},
#  {'label': 'CRICKET NOTES. (CROMARG_18971012_ARTICLE20)',
#   'value': 'CROMARG_18971012_ARTICLE20'},
#  {'label': 'BANKRUPTCY OF W. L. REES. (AS_18850908_ARTICLE21)',
#   'value': 'AS_18850908_ARTICLE21'},
#  {'label': 'TWO MEN MISSING. (AS_18930118_ARTICLE35)',
#   'value': 'AS_18930118_ARTICLE35'},
#  {'label': 'PORT OF ONEHUNGA. (AS_18930925_ARTICLE68)',
#   'value': 'AS_18930925_ARTICLE68'},
#  {'label': 'TELEGRAMS. (AS_18880906_ARTICLE75)',
#   'value': 'AS_18880906_ARTICLE75'},
#  {'label': 'FAMILY GHOSTS. (AS_18981110_ARTICLE22)',
#   'value': 'AS_18981110_ARTICLE22'},
#  {'label': 'WHITE SLAVES IN KHARTOUM. (AS_18880822_ARTICLE51)',
#   'value': 'AS_18880822_ARTICLE51'},
#  {'label': 'UNTITLED (CROMARG_18720220_ARTICLE16)',
#   'value': 'CROMARG_18720220_ARTICLE16'},
#  {'label': 'EXPORTS. (AS_18700707_ARTICLE3)', 'value': 'AS_18700707_ARTICLE3'},
#  {'label': 'ARRIVALS. (AS_18761220_ARTICLE1)',
#   'value': 'AS_18761220_ARTICLE1'},
#  {'label': 'THE SIEGE OF LADYSMITH. (AS_18991213_ARTICLE76)',
#   'value': 'AS_18991213_ARTICLE76'},
#  {'label': 'THE STEAMER OONAH. (AS_18950925_ARTICLE48)',
#   'value': 'AS_18950925_ARTICLE48'},
#  {'label': 'CABLEGRAMS. (AS_18811123_ARTICLE20)',
#   'value': 'AS_18811123_ARTICLE20'},
#  {'label': 'RUSSIAN CROPS. (AS_18910807_ARTICLE43)',
#   'value': 'AS_18910807_ARTICLE43'},
#  {'label': 'PROVINCIAL AND COLONIAL. (CROMARG_18801221_ARTICLE14)',
#   'value': 'CROMARG_18801221_ARTICLE14'},
#  {'label': 'UNTITLED (CROMARG_18980906_ARTICLE28)',
#   'value': 'CROMARG_18980906_ARTICLE28'},
#  {'label': 'AMONG THE ICEBERGS. (AS_18950417_ARTICLE74)',
#   'value': 'AS_18950417_ARTICLE74'},
#  {'label': 'Meetings, Entertainments, Etc. (AS_18810716_ARTICLE8)',
#   'value': 'AS_18810716_ARTICLE8'},
#  {'label': 'ENGLAND AND AFRICA. (AS_18950415_ARTICLE42)',
#   'value': 'AS_18950415_ARTICLE42'},
#  {'label': 'S.M. COURT, CROMWELL. (CROMARG_18980809_ARTICLE29)',
#   'value': 'CROMARG_18980809_ARTICLE29'},
#  {'label': 'COROMANDEL. (AS_18920823_ARTICLE48)',
#   'value': 'AS_18920823_ARTICLE48'},
#  {'label': 'Seizure of the Oreti. (AS_18880204_ARTICLE102)',
#   'value': 'AS_18880204_ARTICLE102'},
#  {'label': 'OUR GOLDFIELDS. (AS_18920826_ARTICLE61)',
#   'value': 'AS_18920826_ARTICLE61'},
#  {'label': 'RACING. (WI_18660412_ARTICLE30)',
#   'value': 'WI_18660412_ARTICLE30'},
#  {'label': 'A BRUTAL ASSAULT IN MASTERTON. (WDT_18960227_ARTICLE24)',
#   'value': 'WDT_18960227_ARTICLE24'},
#  {'label': 'AUCKLAND Last Night. (TAN_18880407_ARTICLE4)',
#   'value': 'TAN_18880407_ARTICLE4'},
#  {'label': 'AUSTRALIAN FLOODS. (AS_18900403_ARTICLE70)',
#   'value': 'AS_18900403_ARTICLE70'},
#  {'label': 'VERY LATEST. (WDT_18910227_ARTICLE7)',
#   'value': 'WDT_18910227_ARTICLE7'},
#  {'label': 'SPORTING NEWS. (AS_18900513_ARTICLE29)',
#   'value': 'AS_18900513_ARTICLE29'},
#  {'label': 'FOOTBALL NOTES. (WDT_18860309_ARTICLE10)',
#   'value': 'WDT_18860309_ARTICLE10'},
#  {'label': 'SUPREME COURT. Saturday, 26th September, 1846. Before Mr. Justice Chapman. Civil Sittings. (NZSCSG_18460930_ARTICLE4)',
#   'value': 'NZSCSG_18460930_ARTICLE4'},
#  {'label': 'COLONEL KELLY INTERVIEWED. (AS_18970906_ARTICLE66)',
#   'value': 'AS_18970906_ARTICLE66'},
#  {'label': 'Deaths. (AS_18860602_ARTICLE20)',
#   'value': 'AS_18860602_ARTICLE20'},
#  {'label': 'IMPORTS. (AS_18861004_ARTICLE9)', 'value': 'AS_18861004_ARTICLE9'},
#  {'label': 'DROUGHT IN RUSSIA. (AS_18970907_ARTICLE51)',
#   'value': 'AS_18970907_ARTICLE51'},
#  {'label': 'MISCELLANEOUS EXTRACTS. (WI_18631027_ARTICLE18)',
#   'value': 'WI_18631027_ARTICLE18'},
#  {'label': 'THE "Wellington Independent." Wednesday, September 24, 1851. (WI_18510924_ARTICLE5)',
#   'value': 'WI_18510924_ARTICLE5'},
#  {'label': 'Chief Post-office, Auckland. (AS_18870202_ARTICLE5)',
#   'value': 'AS_18870202_ARTICLE5'},
#  {'label': 'THE KIMBERLEY GOLDFIELDS. (AS_18860607_ARTICLE24)',
#   'value': 'AS_18860607_ARTICLE24'},
#  {'label': 'THE BARQUE INDIA. (AS_18900723_ARTICLE28)',
#   'value': 'AS_18900723_ARTICLE28'},
#  {'label': 'CABLEGRAMS. (WDT_18830815_ARTICLE5)',
#   'value': 'WDT_18830815_ARTICLE5'},
#  {'label': 'TARANAKI. (WI_18490825_ARTICLE6)',
#   'value': 'WI_18490825_ARTICLE6'},
#  {'label': 'HOW THE DISASTER HAPPENED. (AS_18861211_ARTICLE31)',
#   'value': 'AS_18861211_ARTICLE31'},
#  {'label': 'UPPER HUTT. (WI_18640830_ARTICLE13)',
#   'value': 'WI_18640830_ARTICLE13'},
#  {'label': 'GREYTOWN CEMETERY. TRUST. (WDT_18930516_ARTICLE15)',
#   'value': 'WDT_18930516_ARTICLE15'},
#  {'label': 'CHRISTCHURCH.  August 8. (NOT_18780809_ARTICLE17)',
#   'value': 'NOT_18780809_ARTICLE17'},
#  {'label': 'MAILS CLOSE. (MEX_18891218_ARTICLE3)',
#   'value': 'MEX_18891218_ARTICLE3'},
#  {'label': 'DUNEDIN. (NOT_18840521_ARTICLE11)',
#   'value': 'NOT_18840521_ARTICLE11'},
#  {'label': "THE MINISTER'S VISIT. (MEX_18881006_ARTICLE22)",
#   'value': 'MEX_18881006_ARTICLE22'},
#  {'label': 'WELLINGTON. June 3, (NOT_18920604_ARTICLE12)',
#   'value': 'NOT_18920604_ARTICLE12'},
#  {'label': 'NEW YEAR HONORS. (MEX_18990103_ARTICLE17)',
#   'value': 'MEX_18990103_ARTICLE17'},
#  {'label': 'OAMARU CRICKET CLUB.  TOWN V. BANKS. (NOT_18800301_ARTICLE18)',
#   'value': 'NOT_18800301_ARTICLE18'},
#  {'label': 'CHRISTCHURCH RACES. (NOT_18831211_ARTICLE11)',
#   'value': 'NOT_18831211_ARTICLE11'},
#  {'label': 'NEW ZEALAND. (MEX_18910630_ARTICLE18)',
#   'value': 'MEX_18910630_ARTICLE18'},
#  {'label': 'SCULLING CHAMPIONSHIP. (MEX_18870713_ARTICLE28)',
#   'value': 'MEX_18870713_ARTICLE28'},
#  {'label': 'UNTITLED (MEX_18990605_ARTICLE51)',
#   'value': 'MEX_18990605_ARTICLE51'},
#  {'label': 'MARLBOROUGH AGRICULTURAL AND PASTORAL ASSOCIATION. (MEX_18820508_ARTICLE27)',
#   'value': 'MEX_18820508_ARTICLE27'},
#  {'label': 'EDUCATIONAL. (MEX_18950211_ARTICLE34)',
#   'value': 'MEX_18950211_ARTICLE34'},
#  {'label': 'DEATH. (NOT_18960413_ARTICLE10)',
#   'value': 'NOT_18960413_ARTICLE10'},
#  {'label': 'DEATH. (MEX_18850922_ARTICLE5)', 'value': 'MEX_18850922_ARTICLE5'},
#  {'label': "STANLEY'S MOVEMENTS. (MEX_18870806_ARTICLE7)",
#   'value': 'MEX_18870806_ARTICLE7'},
#  {'label': 'THE KAIWARRA MURDER. (MEX_18890712_ARTICLE20)',
#   'value': 'MEX_18890712_ARTICLE20'},
#  {'label': 'EGMONT ACCEPTANCES. (MEX_18970204_ARTICLE14)',
#   'value': 'MEX_18970204_ARTICLE14'},
#  {'label': 'LONDON BREADSTUFFS MARKET. (NOT_18780904_ARTICLE11)',
#   'value': 'NOT_18780904_ARTICLE11'},
#  {'label': 'TURNING THE TABLES. (CHP_18950116_ARTICLE20)',
#   'value': 'CHP_18950116_ARTICLE20'},
#  {'label': 'SHIPPING TELEGRAMS. (CHP_18990313_ARTICLE77)',
#   'value': 'CHP_18990313_ARTICLE77'},
#  {'label': 'CHARITABLE AID. (CHP_18950724_ARTICLE42)',
#   'value': 'CHP_18950724_ARTICLE42'},
#  {'label': 'CLIPPINGS. (CHP_18930420_ARTICLE16)',
#   'value': 'CHP_18930420_ARTICLE16'},
#  {'label': '"ALWAYS READY." (CHP_18950615_ARTICLE72)',
#   'value': 'CHP_18950615_ARTICLE72'},
#  {'label': 'MANUFACTURE OF WINE. (CHP_18881013_ARTICLE43)',
#   'value': 'CHP_18881013_ARTICLE43'},
#  {'label': "MOVEMMENTS OF THE UNION STEAMSHIP COMPANY'S STEAMERS. (CHP_18890718_ARTICLE15)",
#   'value': 'CHP_18890718_ARTICLE15'},
#  {'label': 'CHRISTCHURCH MILK SUPPLY. (CHP_18910416_ARTICLE53)',
#   'value': 'CHP_18910416_ARTICLE53'},
#  {'label': 'BIRTH. (DSC_18630525_ARTICLE7)', 'value': 'DSC_18630525_ARTICLE7'},
#  {'label': 'LONDON GRAIN MARKET. (NOT_18901215_ARTICLE24)',
#   'value': 'NOT_18901215_ARTICLE24'},
#  {'label': 'DEATHS. (CHP_18810927_ARTICLE9)',
#   'value': 'CHP_18810927_ARTICLE9'},
#  {'label': 'DUNLOP PACING ARRANGEMENTS. (CHP_18970923_ARTICLE5)',
#   'value': 'CHP_18970923_ARTICLE5'},
#  {'label': 'CHRISTCHURCH. (CHP_18860216_ARTICLE38)',
#   'value': 'CHP_18860216_ARTICLE38'},
#  {'label': 'CRICKET. (CHP_18641031_ARTICLE14)',
#   'value': 'CHP_18641031_ARTICLE14'},
#  {'label': 'PRIMITIVE METHODIST CONFERENCE.  (BY TELEGRAPH.)  Invercargill, January 25. (NOT_18880126_ARTICLE16)',
#   'value': 'NOT_18880126_ARTICLE16'},
#  {'label': 'The Press. SATURDAY, SEPTEMBER 20, 1884. (CHP_18840920_ARTICLE10)',
#   'value': 'CHP_18840920_ARTICLE10'},
#  {'label': 'MEAN TIME OF HIGH WATER AT AUCKLAND. (DSC_18631205_ARTICLE11)',
#   'value': 'DSC_18631205_ARTICLE11'},
#  {'label': 'LANCASTER PARK. (CHP_18931221_ARTICLE8)',
#   'value': 'CHP_18931221_ARTICLE8'},
#  {'label': 'SHIPPING TELEGRAMS. (CHP_18870926_ARTICLE13)',
#   'value': 'CHP_18870926_ARTICLE13'},
#  {'label': 'LAW NOTICES.—THIS DAY. (CHP_18690720_ARTICLE14)',
#   'value': 'CHP_18690720_ARTICLE14'},
#  {'label': 'RIVERTON.  November 4. (NOT_18761106_ARTICLE13)',
#   'value': 'NOT_18761106_ARTICLE13'},
#  {'label': 'CHRISTCHURCH.  January 20. (NOT_18900121_ARTICLE18)',
#   'value': 'NOT_18900121_ARTICLE18'},
#  {'label': 'SUPREME COURT. (CHP_18930802_ARTICLE20)',
#   'value': 'CHP_18930802_ARTICLE20'},
#  {'label': 'PORT OF LYTTELTON. (CHP_18960907_ARTICLE77)',
#   'value': 'CHP_18960907_ARTICLE77'},
#  {'label': 'THE ELBE DISASTER. (CHP_18950302_ARTICLE67)',
#   'value': 'CHP_18950302_ARTICLE67'},
#  {'label': 'LYTTELTON. (CHP_18971126_ARTICLE4)',
#   'value': 'CHP_18971126_ARTICLE4'},
#  {'label': 'LATEST FROM TAURANGA. (CHP_18670311_ARTICLE16)',
#   'value': 'CHP_18670311_ARTICLE16'},
#  {'label': 'THE UNION STEAMSHIP COMPANY. (CHP_18910424_ARTICLE65)',
#   'value': 'CHP_18910424_ARTICLE65'},
#  {'label': 'PORT OF LYTTELTON. (CHP_18840530_ARTICLE1)',
#   'value': 'CHP_18840530_ARTICLE1'},
#  {'label': 'AMERICAN LADIED IN PARIS. (CHP_18650408_ARTICLE7)',
#   'value': 'CHP_18650408_ARTICLE7'},
#  {'label': 'HOUSE OF REPRESENTATIVES. (CHP_18830714_ARTICLE21)',
#   'value': 'CHP_18830714_ARTICLE21'},
#  {'label': 'LAW NOTICES—THIS DAY. (CHP_18940213_ARTICLE69)',
#   'value': 'CHP_18940213_ARTICLE69'},
#  {'label': 'TEMPERANCE. (CHP_18930912_ARTICLE6)',
#   'value': 'CHP_18930912_ARTICLE6'},
#  {'label': 'SHIPPING TELEGRAMS. (CHP_18960912_ARTICLE109)',
#   'value': 'CHP_18960912_ARTICLE109'},
#  {'label': "AUCKLAND LIVE STOCK MARKET.  [Reports for the week ending November 2.] MR. BUCKLAND'S REPORT. (DSC_18661103_ARTICLE4)",
#   'value': 'DSC_18661103_ARTICLE4'},
#  {'label': 'WELLINGTON.  November 13. (NOT_18761114_ARTICLE8)',
#   'value': 'NOT_18761114_ARTICLE8'},
#  {'label': 'TELEGRAPH NOTICE BOARD. (CHP_18850820_ARTICLE3)',
#   'value': 'CHP_18850820_ARTICLE3'},
#  {'label': 'EXPECTED ARRIVALS. (CHP_18940601_ARTICLE78)',
#   'value': 'CHP_18940601_ARTICLE78'},
#  {'label': 'Pandering to Morbid Tastes. (WH_18940804_ARTICLE14)',
#   'value': 'WH_18940804_ARTICLE14'},
#  {'label': 'A FALL FROM A TRAIN. (WH_18990222_ARTICLE12)',
#   'value': 'WH_18990222_ARTICLE12'},
#  {'label': 'BOILING DOWN. (DSC_18670718_ARTICLE24)',
#   'value': 'DSC_18670718_ARTICLE24'},
#  {'label': 'MARRIAGE. (WH_18801105_ARTICLE5)',
#   'value': 'WH_18801105_ARTICLE5'},
#  {'label': 'THE DUNEDIN TRAGEDY. (WH_18800316_ARTICLE15)',
#   'value': 'WH_18800316_ARTICLE15'},
#  {'label': 'KURI BUSH. (OW_18810924_ARTICLE63)',
#   'value': 'OW_18810924_ARTICLE63'},
#  {'label': 'LATE CABLES. (WH_18970927_ARTICLE31)',
#   'value': 'WH_18970927_ARTICLE31'},
#  {'label': 'Light Wanted. (OW_18950110_ARTICLE37)',
#   'value': 'OW_18950110_ARTICLE37'},
#  {'label': 'THE RIDDLER. (OW_18970114_ARTICLE196)',
#   'value': 'OW_18970114_ARTICLE196'},
#  {'label': 'HARBOUR IMPROVEMENTS. (WH_18980606_ARTICLE28)',
#   'value': 'WH_18980606_ARTICLE28'},
#  {'label': 'Wanganui Herald.  (PUBLISHED DAILY.)  FRIDAY, JANUARY 29, 1886.  THE "TUHUA " MUDDLE. (WH_18860129_ARTICLE4)',
#   'value': 'WH_18860129_ARTICLE4'},
#  {'label': 'INQUESTS. (DSC_18641224_ARTICLE28)',
#   'value': 'DSC_18641224_ARTICLE28'},
#  {'label': 'ARRIVAL OF THE ALEXA FROM FOO CHOW. (WH_18791022_ARTICLE1)',
#   'value': 'WH_18791022_ARTICLE1'},
#  {'label': 'DR. MANNING AND THE FENIAN PRISONERS. (DSC_18690618_ARTICLE37)',
#   'value': 'DSC_18690618_ARTICLE37'},
#  {'label': 'Natural History. (OW_18810827_ARTICLE152)',
#   'value': 'OW_18810827_ARTICLE152'},
#  {'label': 'WANGANUI AGRIOULTURAL SOCIETY. (WH_18790731_ARTICLE15)',
#   'value': 'WH_18790731_ARTICLE15'},
#  {'label': 'POST OFFICE. (DSC_18590211_ARTICLE9)',
#   'value': 'DSC_18590211_ARTICLE9'},
#  {'label': 'WEDDING BELLS. (WH_18950815_ARTICLE20)',
#   'value': 'WH_18950815_ARTICLE20'},
#  {'label': "ONEHUNGA.  RESIDENT MAGISTRATE'S COURT.  (Before Captain Symonds.  R.M) (DSC_18700120_ARTICLE39)",
#   'value': 'DSC_18700120_ARTICLE39'},
#  {'label': 'WELLINGTON CHAMBER OF COMMERCE. (WH_18670806_ARTICLE6)',
#   'value': 'WH_18670806_ARTICLE6'},
#  {'label': 'MARRIAGES. (OW_18910108_ARTICLE90)',
#   'value': 'OW_18910108_ARTICLE90'},
#  {'label': 'LATEST EUROPEAN. (WH_18780611_ARTICLE11)',
#   'value': 'WH_18780611_ARTICLE11'},
#  {'label': 'The Daily Southern Cross. (DSC_18700430_ARTICLE17)',
#   'value': 'DSC_18700430_ARTICLE17'},
#  {'label': 'THE CANTERBURY MATCH. (OW_18890815_ARTICLE129)',
#   'value': 'OW_18890815_ARTICLE129'},
#  {'label': 'MINING REGULATIONS UNDER "THE MINES ACT, 1877." (KUMAT_18790327_ARTICLE10)',
#   'value': 'KUMAT_18790327_ARTICLE10'},
#  {'label': "MESSRS, BROGDEN'S NAVVIES, (OW_18730111_ARTICLE4)",
#   'value': 'OW_18730111_ARTICLE4'},
#  {'label': 'OUR SCOTCH LETTER (OW_18850207_ARTICLE14)',
#   'value': 'OW_18850207_ARTICLE14'},
#  {'label': 'THE KUMARA-KAWHAKA AND WAIMEA WATER-RACES. (KUMAT_18840223_ARTICLE12)',
#   'value': 'KUMAT_18840223_ARTICLE12'},
#  {'label': 'DEPARTURES. (HBH_18971027_ARTICLE3)',
#   'value': 'HBH_18971027_ARTICLE3'},
#  {'label': 'EVENING SITTING. (HBH_18930906_ARTICLE23)',
#   'value': 'HBH_18930906_ARTICLE23'},
#  {'label': 'GREECE, (HBH_18960408_ARTICLE24)',
#   'value': 'HBH_18960408_ARTICLE24'},
#  {'label': "OLKS' (OW_18940621_ARTICLE215)",
#   'value': 'OW_18940621_ARTICLE215'},
#  {'label': 'UPPER TAIERI. (OW_18930727_ARTICLE68)',
#   'value': 'OW_18930727_ARTICLE68'},
#  {'label': 'SUBURBAN CONFERENCE. (OW_18770210_ARTICLE29)',
#   'value': 'OW_18770210_ARTICLE29'},
#  {'label': 'Mr. J. H. Blackburne. (OW_18850411_ARTICLE100)',
#   'value': 'OW_18850411_ARTICLE100'},
#  {'label': "HOOLEY'S CASE. (HBH_18981118_ARTICLE38)",
#   'value': 'HBH_18981118_ARTICLE38'},
#  {'label': 'TO CORRESPONDENTS. (OW_18850103_ARTICLE37)',
#   'value': 'OW_18850103_ARTICLE37'},
#  {'label': 'Station, Farm,& Garden. (OW_18781012_ARTICLE1)',
#   'value': 'OW_18781012_ARTICLE1'},
#  {'label': '1851 { OTAGO WITNESS. }1893 (OW_18930406_ARTICLE95)',
#   'value': 'OW_18930406_ARTICLE95'},
#  {'label': 'EXCITING CHASE. (HNS_18830706_ARTICLE21)',
#   'value': 'HNS_18830706_ARTICLE21'},
#  {'label': 'SANATORIUM. (HNS_18830622_ARTICLE18)',
#   'value': 'HNS_18830622_ARTICLE18'},
#  {'label': 'MESSRS F. R. JACKSON AND COS STOCK REPORT. (HNS_18940818_ARTICLE6)',
#   'value': 'HNS_18940818_ARTICLE6'},
#  {'label': 'THE CONTAGIOUS DISEASES (ANIMALS) BILL. (HNS_18840522_ARTICLE36)',
#   'value': 'HNS_18840522_ARTICLE36'},
#  {'label': 'Floods at Westport. (HNS_18960327_ARTICLE6)',
#   'value': 'HNS_18960327_ARTICLE6'},
#  {'label': 'ARRIVAL. (HBH_18790829_ARTICLE2)',
#   'value': 'HBH_18790829_ARTICLE2'},
#  {'label': 'TELEGRAPHIC SHIPPING. (HBH_18950911_ARTICLE6)',
#   'value': 'HBH_18950911_ARTICLE6'},
#  {'label': 'LATEST CABLE NEWS. (HNS_18810720_ARTICLE8)',
#   'value': 'HNS_18810720_ARTICLE8'},
#  {'label': 'ENGLAND. (HBH_18880505_ARTICLE19)',
#   'value': 'HBH_18880505_ARTICLE19'},
#  {'label': 'RENTED LAND VERSUS FREE. (HBH_18791223_ARTICLE22)',
#   'value': 'HBH_18791223_ARTICLE22'},
#  {'label': 'PROJECTED DEPARTURES. (HBH_18800812_ARTICLE5)',
#   'value': 'HBH_18800812_ARTICLE5'},
#  {'label': 'COLONIAL BANK. DUNEDIN, July 19. (HNS_18830719_ARTICLE19)',
#   'value': 'HNS_18830719_ARTICLE19'},
#  {'label': 'CRICKET (TH_18990509_ARTICLE18)',
#   'value': 'TH_18990509_ARTICLE18'},
#  {'label': 'LOCAL MARKET REPORT. (HNS_18991209_ARTICLE1)',
#   'value': 'HNS_18991209_ARTICLE1'},
#  {'label': 'STRUCK BY LIGHTNING. (HNS_18830905_ARTICLE14)',
#   'value': 'HNS_18830905_ARTICLE14'},
#  {'label': 'Wellington Gossip. (HBH_18880515_ARTICLE20)',
#   'value': 'HBH_18880515_ARTICLE20'},
#  {'label': 'Local Intelligence. (TH_18650415_ARTICLE5)',
#   'value': 'TH_18650415_ARTICLE5'},
#  {'label': 'Telegraphic. (HBH_18950802_ARTICLE20)',
#   'value': 'HBH_18950802_ARTICLE20'},
#  {'label': 'CORRESPONDENCE. (HBH_18850530_ARTICLE17)',
#   'value': 'HBH_18850530_ARTICLE17'},
#  {'label': 'THEYARRA TRAGEDY (HBH_18990227_ARTICLE18)',
#   'value': 'HBH_18990227_ARTICLE18'},
#  {'label': 'NAPIER. (HBH_18940424_ARTICLE29)',
#   'value': 'HBH_18940424_ARTICLE29'},
#  {'label': 'THE CHOLERA. (AG_18920920_ARTICLE15)',
#   'value': 'AG_18920920_ARTICLE15'},
#  {'label': 'TELEGRAPHIC. (AG_18800511_ARTICLE12)',
#   'value': 'AG_18800511_ARTICLE12'},
#  {'label': "THE MINERS' STRIKE. (PBH_18880918_ARTICLE15)",
#   'value': 'PBH_18880918_ARTICLE15'},
#  {'label': 'UNTITLED (PBH_18920121_ARTICLE16)',
#   'value': 'PBH_18920121_ARTICLE16'},
#  {'label': 'Native Land Court Bill. (PBH_18941013_ARTICLE5)',
#   'value': 'PBH_18941013_ARTICLE5'},
#  {'label': 'NEW AIDE-DE-CAMPE TO GOVERNOR. (TH_18940111_ARTICLE13)',
#   'value': 'TH_18940111_ARTICLE13'},
#  {'label': 'Renunciation of the German and Belgian Commercial Treaties. (AG_18970804_ARTICLE19)',
#   'value': 'AG_18970804_ARTICLE19'},
#  {'label': 'DUNEDIN MARKETS. (AG_18961128_ARTICLE30)',
#   'value': 'AG_18961128_ARTICLE30'},
#  {'label': 'CABLE MESSAGES.  British and Foreign Telegrams (TH_18881120_ARTICLE22)',
#   'value': 'TH_18881120_ARTICLE22'},
#  {'label': 'MAIL NOTICE. (PBH_18921215_ARTICLE4)',
#   'value': 'PBH_18921215_ARTICLE4'},
#  {'label': 'THE LORD LIEUTENANT. (AG_18890412_ARTICLE8)',
#   'value': 'AG_18890412_ARTICLE8'},
#  {'label': 'UNTITLED (AG_18920725_ARTICLE20)',
#   'value': 'AG_18920725_ARTICLE20'},
#  {'label': 'AUCKLAND—October 24. (TH_18741028_ARTICLE5)',
#   'value': 'TH_18741028_ARTICLE5'},
#  {'label': 'MIXING BOYS AND GIRLS IN PUBLIC SCHOOLS. (PBH_18831024_ARTICLE8)',
#   'value': 'PBH_18831024_ARTICLE8'},
#  {'label': "Today's Telegraphic Shipping. (PBH_18901106_ARTICLE3)",
#   'value': 'PBH_18901106_ARTICLE3'},
#  {'label': 'PORT OF NEW PLYMOUTH. (TH_18810831_ARTICLE1)',
#   'value': 'TH_18810831_ARTICLE1'},
#  {'label': 'LOCAL AND GENERAL. (AG_18900217_ARTICLE2)',
#   'value': 'AG_18900217_ARTICLE2'},
#  {'label': 'SHIPPING INTELLIGENCE. (PBH_18931111_ARTICLE2)',
#   'value': 'PBH_18931111_ARTICLE2'},
#  {'label': 'PETROLEUM SYNDICATE. (TH_18941005_ARTICLE26)',
#   'value': 'TH_18941005_ARTICLE26'},
#  {'label': 'A NEW CURE. (TH_18740617_ARTICLE22)',
#   'value': 'TH_18740617_ARTICLE22'},
#  {'label': 'POISON IN THE ASHES (AG_18880218_ARTICLE41)',
#   'value': 'AG_18880218_ARTICLE41'},
#  {'label': 'THE LANCASHIRE PLATE. (AG_18890923_ARTICLE39)',
#   'value': 'AG_18890923_ARTICLE39'},
#  {'label': 'UNTITLED (TH_18880110_ARTICLE24)',
#   'value': 'TH_18880110_ARTICLE24'},
#  {'label': 'ENGLISH TEAM OF FOOTBALLERS. (AG_18871111_ARTICLE29)',
#   'value': 'AG_18871111_ARTICLE29'},
#  {'label': 'TO-DAY’S TELEGRAMS. (AG_18860720_ARTICLE19)',
#   'value': 'AG_18860720_ARTICLE19'},
#  {'label': 'ASHBURTON MARKETS. (AG_18970304_ARTICLE22)',
#   'value': 'AG_18970304_ARTICLE22'},
#  {'label': 'MYSTEEIOUS MURDER IN MELBOURNE. (TH_18940507_ARTICLE18)',
#   'value': 'TH_18940507_ARTICLE18'},
#  {'label': 'JUBILEE PRODUCE SHOW. (TH_18910620_ARTICLE24)',
#   'value': 'TH_18910620_ARTICLE24'},
#  {'label': 'Diseases in Stock. (PBH_18950301_ARTICLE9)',
#   'value': 'PBH_18950301_ARTICLE9'},
#  {'label': 'OBITUARY. (TH_18980909_ARTICLE21)',
#   'value': 'TH_18980909_ARTICLE21'},
#  {'label': 'COMMERCIAL. (AG_18990210_ARTICLE23)',
#   'value': 'AG_18990210_ARTICLE23'},
#  {'label': 'The Storm in New South Wales. (AG_18930310_ARTICLE12)',
#   'value': 'AG_18930310_ARTICLE12'},
#  {'label': 'POLICE COURT. (TH_18841205_ARTICLE3)',
#   'value': 'TH_18841205_ARTICLE3'},
#  {'label': 'DEATH. (TH_18941203_ARTICLE9)', 'value': 'TH_18941203_ARTICLE9'},
#  {'label': 'THE Deeming murders. (AG_18920402_ARTICLE20)',
#   'value': 'AG_18920402_ARTICLE20'},
#  {'label': 'POLLING DAY. (NEM_18991205_ARTICLE25)',
#   'value': 'NEM_18991205_ARTICLE25'},
#  {'label': 'Election of West Coast School  Committees. (NEM_18960429_ARTICLE44)',
#   'value': 'NEM_18960429_ARTICLE44'},
#  {'label': 'PARLIAMENTARY. (PBH_18860804_ARTICLE6)',
#   'value': 'PBH_18860804_ARTICLE6'},
#  {'label': 'NEW ZEALAND. (NEM_18840426_ARTICLE12)',
#   'value': 'NEM_18840426_ARTICLE12'},
#  {'label': 'CRICKET. (PBH_18990823_ARTICLE26)',
#   'value': 'PBH_18990823_ARTICLE26'},
#  {'label': 'NOTICE TO CORRESPONDENTS. (NEM_18680904_ARTICLE4)',
#   'value': 'NEM_18680904_ARTICLE4'},
#  {'label': 'COLONIAL PARLIAMENT. (DUNST_18680814_ARTICLE6)',
#   'value': 'DUNST_18680814_ARTICLE6'},
#  {'label': 'PLACEB MINING IN BRITISH COLOMBIA. (NEM_18990120_ARTICLE37)',
#   'value': 'NEM_18990120_ARTICLE37'},
#  {'label': 'Passenger Missing from the Rotorua. (NEM_18900220_ARTICLE23)',
#   'value': 'NEM_18900220_ARTICLE23'},
#  {'label': 'THE MAINE DISASTER. (NEM_18980222_ARTICLE26)',
#   'value': 'NEM_18980222_ARTICLE26'},
#  {'label': 'Action for Slander. (NEM_18921105_ARTICLE12)',
#   'value': 'NEM_18921105_ARTICLE12'},
#  {'label': 'UNTITLED (NEM_18851024_ARTICLE19)',
#   'value': 'NEM_18851024_ARTICLE19'},
#  {'label': 'UNTITLED (NEM_18720805_ARTICLE7)',
#   'value': 'NEM_18720805_ARTICLE7'},
#  {'label': 'Nelson en Fete. (PBH_18890926_ARTICLE9)',
#   'value': 'PBH_18890926_ARTICLE9'},
#  {'label': 'The Poverty Bay Herald  AND  East Coast News Letter.  PUBLISHED EVERY EVENING. (PBH_18801126_ARTICLE2)',
#   'value': 'PBH_18801126_ARTICLE2'},
#  {'label': 'THE BANKING COMMITTEE. (NEM_18960916_ARTICLE16)',
#   'value': 'NEM_18960916_ARTICLE16'},
#  {'label': "SEAMAN'S INSTITUTE. (ODT_18760119_ARTICLE14)",
#   'value': 'ODT_18760119_ARTICLE14'},
#  {'label': 'OMNIUM GATHERUM. (ODT_18910209_ARTICLE37)',
#   'value': 'ODT_18910209_ARTICLE37'},
#  {'label': 'HOSPITAL TRUSTEES. (ODT_18940818_ARTICLE44)',
#   'value': 'ODT_18940818_ARTICLE44'},
#  {'label': 'SHIPPING TELEGRAMS. (ODT_18770801_ARTICLE4)',
#   'value': 'ODT_18770801_ARTICLE4'},
#  {'label': 'THE WAR IN SAMOA. (THS_18930808_ARTICLE11)',
#   'value': 'THS_18930808_ARTICLE11'},
#  {'label': '"CIVIS" V. FREETHOUGHT. (ODT_18810319_ARTICLE34)',
#   'value': 'ODT_18810319_ARTICLE34'},
#  {'label': 'OUR VOLUNTEERS. (ODT_18841202_ARTICLE31)',
#   'value': 'ODT_18841202_ARTICLE31'},
#  {'label': 'WELLINGTON. (ODT_18640928_ARTICLE12)',
#   'value': 'ODT_18640928_ARTICLE12'},
#  {'label': 'TELEGRAMS. (ODT_18751109_ARTICLE8)',
#   'value': 'ODT_18751109_ARTICLE8'},
#  {'label': 'Commercial. (THS_18980131_ARTICLE38)',
#   'value': 'THS_18980131_ARTICLE38'},
#  {'label': 'POST OFFICE NOTICES. (THS_18751124_ARTICLE4)',
#   'value': 'THS_18751124_ARTICLE4'},
#  {'label': 'UNTITLED (ODT_18680603_ARTICLE6)',
#   'value': 'ODT_18680603_ARTICLE6'},
#  {'label': 'PORT CHALMERS REGATTA. (ODT_18620527_ARTICLE3)',
#   'value': 'ODT_18620527_ARTICLE3'},
#  {'label': 'THE GROWTH OF THE EMPIRE. (ODT_18990425_ARTICLE18)',
#   'value': 'ODT_18990425_ARTICLE18'},
#  {'label': 'A NEW GOLD AND ORE SAYING APPARATUS. (ODT_18890629_ARTICLE29)',
#   'value': 'ODT_18890629_ARTICLE29'},
#  {'label': 'CUSTOMS REVENUE. (ODT_18830412_ARTICLE14)',
#   'value': 'ODT_18830412_ARTICLE14'},
#  {'label': 'HE OBEYED ORDERS. (THS_18940124_ARTICLE5)',
#   'value': 'THS_18940124_ARTICLE5'},
#  {'label': 'MEETING OF CREDITORS. (ODT_18850608_ARTICLE6)',
#   'value': 'ODT_18850608_ARTICLE6'},
#  {'label': 'THE IMPERIAL PARLIAMENT. (ODT_18841027_ARTICLE13)',
#   'value': 'ODT_18841027_ARTICLE13'},
#  {'label': 'SHIPPING. (ODT_18731127_ARTICLE12)',
#   'value': 'ODT_18731127_ARTICLE12'},
#  {'label': 'CHRISTCHURCH. (THS_18810222_ARTICLE9)',
#   'value': 'THS_18810222_ARTICLE9'},
#  {'label': 'FOST OFFICE NOTICES. (ODT_18950620_ARTICLE12)',
#   'value': 'ODT_18950620_ARTICLE12'},
#  {'label': 'COMMERCIAL CABLEGRAMS. (ODT_18990105_ARTICLE45)',
#   'value': 'ODT_18990105_ARTICLE45'},
#  {'label': 'CITY POLICE COURT. (ODT_18770305_ARTICLE16)',
#   'value': 'ODT_18770305_ARTICLE16'},
#  {'label': 'THE CHOLERA. Colonial Precautions. (THS_18920901_ARTICLE11)',
#   'value': 'THS_18920901_ARTICLE11'},
#  {'label': 'PROVINCIAL COUNCIL. (TC_18710509_ARTICLE8)',
#   'value': 'TC_18710509_ARTICLE8'},
#  {'label': 'BIRTH. (TC_18851214_ARTICLE3)', 'value': 'TC_18851214_ARTICLE3'},
#  {'label': 'THAMES STOCK EXCHANGE. (THS_18910827_ARTICLE8)',
#   'value': 'THS_18910827_ARTICLE8'},
#  {'label': 'CABLEGRAMS (TC_18850305_ARTICLE8)',
#   'value': 'TC_18850305_ARTICLE8'},
#  {'label': 'GENERAL ORDER. (TC_18601110_ARTICLE4)',
#   'value': 'TC_18601110_ARTICLE4'},
#  {'label': 'CITY COUNCIL. (TC_18810604_ARTICLE5)',
#   'value': 'TC_18810604_ARTICLE5'},
#  {'label': 'DEATHS. (THS_18850418_ARTICLE7)',
#   'value': 'THS_18850418_ARTICLE7'},
#  {'label': 'THEATRE ROYAL. (TC_18781205_ARTICLE8)',
#   'value': 'TC_18781205_ARTICLE8'},
#  {'label': 'Dealing with Truants. (TC_18931021_ARTICLE24)',
#   'value': 'TC_18931021_ARTICLE24'},
#  {'label': 'ELECTION PETITION. (TC_18930911_ARTICLE12)',
#   'value': 'TC_18930911_ARTICLE12'},
#  {'label': 'Commercial. (TC_18590204_ARTICLE2)',
#   'value': 'TC_18590204_ARTICLE2'},
#  {'label': 'Evening Star Office. (THS_18790201_ARTICLE4)',
#   'value': 'THS_18790201_ARTICLE4'},
#  {'label': 'GLEANINGS. (TC_18830821_ARTICLE16)',
#   'value': 'TC_18830821_ARTICLE16'},
#  {'label': 'NELSON. (THS_18790129_ARTICLE13)',
#   'value': 'THS_18790129_ARTICLE13'},
#  {'label': 'INTERPROVINCIAL NEWS. (OAM_18990511_ARTICLE2)',
#   'value': 'OAM_18990511_ARTICLE2'},
#  {'label': 'THE DYNAMITE PARTY. (IT_18840620_ARTICLE6)',
#   'value': 'IT_18840620_ARTICLE6'},
#  {'label': 'INTERPROVINCIAL NEWS. (OAM_18980127_ARTICLE25)',
#   'value': 'OAM_18980127_ARTICLE25'},
#  {'label': 'University Senate. (OAM_18970305_ARTICLE19)',
#   'value': 'OAM_18970305_ARTICLE19'},
#  {'label': 'GREYMOUTH J.C. MEETING. (IT_18911215_ARTICLE6)',
#   'value': 'IT_18911215_ARTICLE6'},
#  {'label': 'ABSTRACT OF SALES. (OAM_18990515_ARTICLE12)',
#   'value': 'OAM_18990515_ARTICLE12'},
#  {'label': 'CORRESPONDENCE. (IT_18960619_ARTICLE15)',
#   'value': 'IT_18960619_ARTICLE15'},
#  {'label': 'THE DREYFUS CASE. (OAM_18981007_ARTICLE9)',
#   'value': 'OAM_18981007_ARTICLE9'},
#  {'label': 'RISING AND SETTING OP THE SUN. (PATM_18770606_ARTICLE3)',
#   'value': 'PATM_18770606_ARTICLE3'},
#  {'label': 'TELEGRAMS. (IT_18911121_ARTICLE6)',
#   'value': 'IT_18911121_ARTICLE6'},
#  {'label': 'OPENING OF PARLIAMENT. (OAM_18970407_ARTICLE22)',
#   'value': 'OAM_18970407_ARTICLE22'},
#  {'label': 'SIR GEORGE GREY AT AUCKLAND. (OAM_18800512_ARTICLE10)',
#   'value': 'OAM_18800512_ARTICLE10'},
#  {'label': 'PERSONAL ANNOUNCEMENTS. (OAM_18880507_ARTICLE4)',
#   'value': 'OAM_18880507_ARTICLE4'},
#  {'label': 'HORRIBLE SUICIDE IN OTAGO. (PATM_18830615_ARTICLE21)',
#   'value': 'PATM_18830615_ARTICLE21'},
#  {'label': "RESIDENT MAGISTRATE'S COURT (IT_18780703_ARTICLE2)",
#   'value': 'IT_18780703_ARTICLE2'},
#  {'label': 'INTERPROVINCIAL NEWS. (OAM_18990318_ARTICLE15)',
#   'value': 'OAM_18990318_ARTICLE15'},
#  {'label': 'AUSTRALIAN NEWS. (OAM_18890906_ARTICLE17)',
#   'value': 'OAM_18890906_ARTICLE17'},
#  {'label': 'The Patea Mail. Established 1875. Be Just, and Fear Not. MONDAY, AUGUST 16, 1886. NEWS OF THE DAY. (PATM_18860816_ARTICLE4)',
#   'value': 'PATM_18860816_ARTICLE4'},
#  {'label': 'PORT OF FOXTON. (MH_18960707_ARTICLE1)',
#   'value': 'MH_18960707_ARTICLE1'},
#  {'label': 'TEMUKA TOWN BOARD. (TEML_18970603_ARTICLE18)',
#   'value': 'TEML_18970603_ARTICLE18'},
#  {'label': 'GERALDINE FARMERS’ CLUB. (TEML_18940719_ARTICLE11)',
#   'value': 'TEML_18940719_ARTICLE11'},
#  {'label': 'TELEGRAMS. (TEML_18941215_ARTICLE2)',
#   'value': 'TEML_18941215_ARTICLE2'},
#  {'label': 'An Invaluable Discovery. (MH_18980602_ARTICLE23)',
#   'value': 'MH_18980602_ARTICLE23'},
#  {'label': 'DOCTORS WANTED. (PATM_18800513_ARTICLE7)',
#   'value': 'PATM_18800513_ARTICLE7'},
#  {'label': 'GORE POST OFFICE. (ME_18980526_ARTICLE17)',
#   'value': 'ME_18980526_ARTICLE17'},
#  {'label': 'LOCAL AND GENERAL. (TEML_18871229_ARTICLE8)',
#   'value': 'TEML_18871229_ARTICLE8'},
#  {'label': 'Happy islands in the South Seas. (MH_18990525_ARTICLE17)',
#   'value': 'MH_18990525_ARTICLE17'},
#  {'label': 'Late Colonial News (ME_18930310_ARTICLE23)',
#   'value': 'ME_18930310_ARTICLE23'},
#  {'label': 'Melbourne, July 7. (TEML_18850709_ARTICLE2)',
#   'value': 'TEML_18850709_ARTICLE2'},
#  {'label': 'Tuapeka Times.  AND GOLDFIELDS REPORTER AND ADVERTISER.  SATURDAY, SEPTEMBER 1, 1888.  "MEASURES, NOT MEN."  THE FROZEN MEAT TRADE. (TT_18880901_ARTICLE2)',
#   'value': 'TT_18880901_ARTICLE2'},
#  {'label': 'SHIPPING. (THA_18791223_ARTICLE1)',
#   'value': 'THA_18791223_ARTICLE1'},
#  {'label': 'ANOTHER SWINDLE. (TT_18930927_ARTICLE44)',
#   'value': 'TT_18930927_ARTICLE44'},
#  {'label': 'WIND AND WEATHER.-January 26. (THA_18750127_ARTICLE3)',
#   'value': 'THA_18750127_ARTICLE3'},
#  {'label': 'SPECIAL TELEGRAMS. (THA_18750819_ARTICLE4)',
#   'value': 'THA_18750819_ARTICLE4'},
#  {'label': 'JUBILEE OF OTAGO. (TT_18980219_ARTICLE16)',
#   'value': 'TT_18980219_ARTICLE16'},
#  {'label': 'THE FAR EAST. (THA_18980119_ARTICLE12)',
#   'value': 'THA_18980119_ARTICLE12'},
#  {'label': 'BRITISH AND FOREIGN. (TT_18830829_ARTICLE23)',
#   'value': 'TT_18830829_ARTICLE23'},
#  {'label': 'THE  Manawatu Times.  SATURDAY, NOV. 27, 1880  THE MILK IN THE COCOA NUT. (MT_18801127_ARTICLE2)',
#   'value': 'MT_18801127_ARTICLE2'},
#  {'label': 'SHOCKING MURDERS. (TEML_18960903_ARTICLE13)',
#   'value': 'TEML_18960903_ARTICLE13'},
#  {'label': "NOVELTY IN HATCHING DUCK'S EGGS. (TT_18951016_ARTICLE44)",
#   'value': 'TT_18951016_ARTICLE44'},
#  {'label': 'HENRY WARD BEECHER ON  MR GLADSTONE. (TT_18820927_ARTICLE24)',
#   'value': 'TT_18820927_ARTICLE24'},
#  {'label': 'HARDSHIPS OF COMPULSORY PILOTAGE. (THA_18760711_ARTICLE19)',
#   'value': 'THA_18760711_ARTICLE19'},
#  {'label': 'SPORTING. (THA_18851111_ARTICLE11)',
#   'value': 'THA_18851111_ARTICLE11'},
#  {'label': 'Cooking Recipes. (TT_18891130_ARTICLE38)',
#   'value': 'TT_18891130_ARTICLE38'},
#  {'label': 'PARLIAMENTARY. (THA_18961011_ARTICLE19)',
#   'value': 'THA_18961011_ARTICLE19'},
#  {'label': 'The Cyumide Process. (THA_18980624_ARTICLE44)',
#   'value': 'THA_18980624_ARTICLE44'},
#  {'label': 'SALES BY AUCTION.. (WCT_18870224_ARTICLE4)',
#   'value': 'WCT_18870224_ARTICLE4'},
#  {'label': 'TELEGRAMS. (WCT_18680812_ARTICLE2)',
#   'value': 'WCT_18680812_ARTICLE2'},
#  {'label': 'THE WEEK. (TO_18850418_ARTICLE65)',
#   'value': 'TO_18850418_ARTICLE65'},
#  {'label': 'CHRISTMAS ACCUSTOMS. (TO_18901227_ARTICLE20)',
#   'value': 'TO_18901227_ARTICLE20'},
#  {'label': 'POSTAL NOTICES, (WCT_18900910_ARTICLE6)',
#   'value': 'WCT_18900910_ARTICLE6'},
#  {'label': 'NOTICE TO CORRESPONDENTS (WCT_18960811_ARTICLE4)',
#   'value': 'WCT_18960811_ARTICLE4'},
#  {'label': 'COACH TIME TABLE. (WCT_18930116_ARTICLE4)',
#   'value': 'WCT_18930116_ARTICLE4'},
#  {'label': 'NOTICE TO CORRESPONDENTS. (WCT_18930614_ARTICLE6)',
#   'value': 'WCT_18930614_ARTICLE6'},
#  {'label': 'SPECIAL CABLE NEWS. (WCT_18840609_ARTICLE6)',
#   'value': 'WCT_18840609_ARTICLE6'},
#  {'label': 'WIND AND WEATHER .REPORT. (WCT_18680414_ARTICLE3)',
#   'value': 'WCT_18680414_ARTICLE3'},
#  {'label': 'BRITISH AND FOREIGN. (WCT_18810418_ARTICLE8)',
#   'value': 'WCT_18810418_ARTICLE8'},
#  {'label': 'Grounding of"the Ruapehu. (TO_18970116_ARTICLE27)',
#   'value': 'TO_18970116_ARTICLE27'},
#  {'label': 'UNTITLED (MS_18850323_ARTICLE15)',
#   'value': 'MS_18850323_ARTICLE15'},
#  {'label': 'West Coast Times.  WEDNESDAY, NOVEMBER 30, 1881. (WCT_18811130_ARTICLE5)',
#   'value': 'WCT_18811130_ARTICLE5'},
#  {'label': 'ACCIDENTS AND FATALITIES. (LT_18910303_ARTICLE30)',
#   'value': 'LT_18910303_ARTICLE30'},
#  {'label': 'Throwing Boiling Water. (TS_18830522_ARTICLE23)',
#   'value': 'TS_18830522_ARTICLE23'},
#  {'label': 'LYTTELTON. (TS_18830903_ARTICLE1)',
#   'value': 'TS_18830903_ARTICLE1'},
#  {'label': '" The Spectator" on the Dominion of Australia. (NEM_18891104_ARTICLE18)',
#   'value': 'NEM_18891104_ARTICLE18'},
#  {'label': 'PUBLIC SERVICE ASSOCIATION. (LT_18910408_ARTICLE30)',
#   'value': 'LT_18910408_ARTICLE30'},
#  {'label': 'Marine Engineers. (TC_18980421_ARTICLE33)',
#   'value': 'TC_18980421_ARTICLE33'},
#  {'label': 'The Paris Exhibition. (NEM_18891106_ARTICLE13)',
#   'value': 'NEM_18891106_ARTICLE13'}]

# %% [markdown]
# The following code sets up and runs the dashboard.

# %%
app = JupyterDash(__name__, external_stylesheets=['https://codepen.io/chriddyp/pen/bWLwgP.css'])

#For readability, the control panel is defined before the full app layout.
control_panel = [
    dash_html.P('Readable?'),
    dcc.RadioItems(
        id='readable-radio',
        options=[
            {'label': 'True', 'value': True},
            {'label': 'False', 'value': False}
        ]
    ),
    dash_html.P('Philosophy?'),
    dcc.RadioItems(
        id='philosophy-radio',
        options=[
            {'label': 'True', 'value': True},
            {'label': 'False', 'value': False}
        ]
    ),
    dash_html.P('Philosophy Type?'),
    dcc.RadioItems(
        id='phil-type-radio',
        options=[
            {'label': 'Religion/Science', 'value': 'r'},
            {'label': 'Ethics/Politics', 'value': 'e'},
            {'label': 'Other', 'value': 'o'},
            {'label': 'N/A', 'value': None}
        ]
    ),
    dash_html.P('Writing Type?'),
    dcc.RadioItems(
        id='write-type-radio',
        options=[
            {'label': 'Report of public event', 'value': 'p'},
            {'label': 'Letter to editor', 'value': 'l'},
            {'label': 'First order', 'value': 'f'},
            {'label': 'N/A', 'value': None}
        ]
    ),
    dash_html.P('Notes:'),
    dcc.Textarea(
        id='notes-area',
        style={'width': '100%'}
    ),
    dash_html.Button('Update', id='submit-val', n_clicks=0, style={'margin':'5px'}),
    dash_html.P(id='update-message', style={'display':'none'}) # This div allows the update button to work.
]

app.layout = dash_html.Div([
    dash_html.H2('Label Newspaper Items'),
    dash_html.P('Item'),
    dcc.Dropdown(
        id='item-selection',
        options=item_names_formatted,
        value=item_names_formatted[0]['value'],
        style={'width': '80%', 'margin': '10px'}
    ),
    dash_html.Div([
        dash_html.Div(
            dash_html.Div(
                dcc.Markdown(
                    id='article-display',
                    children=text_as_markdown(to_label.index[0], to_label),
                ),
            style={
                'width': '700px',
                'margin': 'auto'
                }    
            ),
        style={
                'width': '70%', 
                'display': 'inline-block',
                'padding': '15px',
                'margin': '10px'
            }
        ),
        dash_html.Div(
            control_panel,
            style={
                'width': '15%', 
                'display': 'inline-block', 
                'vertical-align': 'top', 
                'padding': '50px',
                'border': 'solid',
                #'position': 'fixed',
                'margin': '10px'
            }
        )
    ])    
])

# When new item chosen, load item text and any labels.
@app.callback(
    [Output(component_id='article-display', component_property='children'),
    Output(component_id='readable-radio', component_property='value'),
    Output(component_id='philosophy-radio', component_property='value'),
    Output(component_id='phil-type-radio', component_property='value'),
    Output(component_id='write-type-radio', component_property='value'),
    Output(component_id='notes-area', component_property='value')],
    [Input(component_id='item-selection', component_property='value')]
)
def load_new_markdown_and_labels(item_id):
    text = text_as_markdown(item_id, to_label)
    readable = philosophy = phil_type = write_type = notes =  None # default value.
    if item_id in labels.index:
        readable = labels.loc[item_id, 'Readable']
        philosophy = labels.loc[item_id, 'Philosophy']
        phil_type = labels.loc[item_id, 'Philosophy Type']
        write_type = labels.loc[item_id, 'Writing Type']
        notes = labels.loc[item_id, 'Notes']
    return text, readable, philosophy, phil_type, write_type, notes

# Update labels when 'update' button pressed.
@app.callback(
    Output(component_id='update-message', component_property='children'),
    [Input(component_id='submit-val', component_property='n_clicks')],
    [State(component_id='readable-radio', component_property='value'),
    State(component_id='philosophy-radio', component_property='value'),
    State(component_id='phil-type-radio', component_property='value'),
    State(component_id='write-type-radio', component_property='value'),
    State(component_id='item-selection', component_property='value'),
    State(component_id='notes-area', component_property='value')]
)
def update_labels(n_clicks, readable, philosophy, phil_type, write_type, item_id, notes):
    if n_clicks > 0:
        labels.loc[item_id, "Readable"] = readable
        labels.loc[item_id, "Philosophy"] = philosophy
        labels.loc[item_id, "Philosophy Type"] = phil_type
        labels.loc[item_id, "Writing Type"] = write_type
        labels.loc[item_id, "Text"] = to_label.loc[item_id, 'Text']
        labels.loc[item_id, "Notes"] = notes
        labels.to_pickle(f'../Labels/labels_{ITERATION}.tar.gz')
    return 'Labels updated'

if __name__ == '__main__':
    app.run_server(debug=False) # Debug changed to avoid https://github.com/plotly/jupyter-dash/issues/15
# Out:
# C:\Program Files\Anaconda3\envs\CorpusPaper\lib\site-packages\jupyter_dash\jupyter_app.py:139: UserWarning:
#
# The 'environ['werkzeug.server.shutdown']' function is deprecated and will be removed in Werkzeug 2.1.
#
# 127.0.0.1 - - [19/Nov/2021 16:25:32] "GET /_shutdown_d0e76599-6b80-473c-a39b-16a42794875a HTTP/1.1" 200 -
#  * Running on http://127.0.0.1:8050/ (Press CTRL+C to quit)
# 127.0.0.1 - - [19/Nov/2021 16:25:32] "GET /_alive_d0e76599-6b80-473c-a39b-16a42794875a HTTP/1.1" 200 -
# Dash app running on http://127.0.0.1:8050/
# 127.0.0.1 - - [19/Nov/2021 16:25:34] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [19/Nov/2021 16:25:35] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [19/Nov/2021 16:25:35] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [19/Nov/2021 16:25:35] "GET /_dash-component-suites/dash/dcc/async-dropdown.js HTTP/1.1" 304 -
# 127.0.0.1 - - [19/Nov/2021 16:25:35] "GET /_dash-component-suites/dash/dcc/async-markdown.js HTTP/1.1" 304 -
# 127.0.0.1 - - [19/Nov/2021 16:25:35] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [19/Nov/2021 16:25:35] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [19/Nov/2021 16:25:35] "GET /_dash-component-suites/dash/dcc/async-highlight.js HTTP/1.1" 304 -
# 127.0.0.1 - - [19/Nov/2021 16:25:45] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [19/Nov/2021 16:25:53] "POST /_dash-update-component HTTP/1.1" 200 -

# %% [markdown]
# ## Next Step

# %% [markdown]
# Having labelled articles, the next step is to fit models using the 'Model Fit and Application Stages' notebook.
